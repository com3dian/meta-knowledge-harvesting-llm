# %%
import pandas as pd

TASKNAMES = ["subtask1", "subtask2"]
TYPES = ["test", "test_preprocess"]

dataset_loader = dict()

for taskname in TASKNAMES:
    for type in TYPES:
        print(f"Processing {taskname} for {type}")
        prefix = "dataset"
        # Load the data
        
        if taskname == "subtask2" and type == "test_preprocess":
            continue
        data = pd.read_csv(f"{prefix}/{taskname}_{type}.csv")
        dataset_loader[f"{taskname}_{type}"] = data

dataset_loader["subtask1_test"]["claim"] = dataset_loader["subtask1_test_preprocess"]["claim"]

# %%
from nltk.tokenize import sent_tokenize
from rapidfuzz import fuzz
from utils import get_latest_result_by_prefix

from kg_compare import get_src_tgt_dict, get_map_src_tgt_dict, compare_knowledge_graphs_similarity
test_data = dataset_loader["subtask1_test"]

index = 6
claim_nodes, claim_edges = get_latest_result_by_prefix(f"claim_test_{index}_")
reference_nodes, reference_edges = get_latest_result_by_prefix(f"reference_test_{index}_")
reference_content = test_data.at[index, "reference"]

claim_node_list = list(claim_nodes.keys())
reference_node_list = list(reference_nodes.keys())

if claim_node_list == [] or reference_node_list == []:
    print("Claim or reference is empty")
    
    
similarity_matrix = compare_knowledge_graphs_similarity(claim_node_list,
                                                        reference_node_list,
                                                        if_plot=False)
src_tgt_dict = get_src_tgt_dict(similarity_matrix, claim_node_list, reference_node_list)

claim_reference_edge_map = get_map_src_tgt_dict(src_tgt_dict, claim_edges)

def find_best_span_for_all_evidences(reference_edges,
                                     claim_reference_edge_map,
                                     paragraph,
                                     max_window_size=5):
    sentences = sent_tokenize(paragraph)

    best_span_list = []
    for _, reference_edge_list in claim_reference_edge_map.items():
        evidence_edges = set(reference_edge_list) & set(reference_edges.keys())

        for evidence_edge in evidence_edges:
            reference_edge = reference_edges[evidence_edge]

            best_score = -1
            best_span = None

            for window_size in range(1, min(max_window_size, len(sentences)) + 1):
                for i in range(len(sentences) - window_size + 1):
                    window = ' '.join(sentences[i:i+window_size])
                    score = fuzz.ratio(reference_edge[0]["description"], window)
                    if score > best_score:
                        best_score = score
                        best_span = (i, i+window_size)
            best_span_list.append(best_span)


    intervals = sorted(set(best_span_list), key=lambda x: x[0])
    merged = []
    for interval in intervals:
        if not merged or merged[-1][1] < interval[0]:
            merged.append(interval)
        else:
            merged[-1] = (merged[-1][0], max(merged[-1][1], interval[1]))

    print(merged)
    evidence_sentences = [' '.join(sentences[merged[i][0]:merged[i][1]]) for i in range(len(merged))]
    return ' '.join(evidence_sentences)


find_best_span_for_all_evidences(reference_edges,
                                 claim_reference_edge_map,
                                 reference_content)

# %%
intervals = [
    (1, 2), (9, 10), (13, 14), (15, 16), (13, 14),
    (1, 2), (9, 10), (13, 14), (15, 16), (13, 14),
    (1, 2), (9, 10), (13, 14), (15, 16), (13, 14),
    (5, 6), (9, 10)
]

# Step 1: Sort and remove duplicates
intervals = sorted(set(intervals), key=lambda x: x[0])

# Step 2: Merge intervals
merged = []
for interval in intervals:
    if not merged or merged[-1][1] < interval[0]:
        merged.append(interval)
    else:
        merged[-1] = (merged[-1][0], max(merged[-1][1], interval[1]))

print(merged)

# %%
claim_reference_edge_map

# %%
import pandas as pd

TASKNAMES = ["subtask1", "subtask2"]
BATCHNAMES = ["batch1", "batch2", "batch3"]

dataset_loader = dict()

for taskname in TASKNAMES:
    for batchname in BATCHNAMES:
        print(f"Processing {taskname} for {batchname}")
        prefix = "dataset/"
        # Load the data
        data = pd.read_csv(f"{prefix}/{taskname}_train_{batchname}.csv")
        dataset_loader[f"{taskname}_{batchname}"] = data

# %%
print(dataset_loader["subtask1_batch2"].answer.tolist()[0])

# %%
print(dataset_loader["subtask1_batch2"].claim.tolist()[0])

# %%
nodes_reference, edges_reference = read_knowledge_graph_from_pickle(files[0])
nodes_claim, edges_claim = read_knowledge_graph_from_pickle(files[1])
for key in nodes_claim.keys():
    if key in nodes_reference.keys():
        print(f"`{key}`")
    else:
        print(f"Key `{key}` not found in nodes_reference")

# %%
for key_src, key_tgt in edges_claim.keys():
    print(f"`{key_src}` -> `{key_tgt}`")

# %%
from geminillm import gemini_complete_if_cache
from json_kv_iml import JsonKVStorage
from operationCheatSheet import preprocessing_claim
from openaillm import openai_embed

LLM_MODEL_NAME = "gemini-2.5-flash-preview-05-20"


kv_global_config = {
    "working_dir": "/tmp",
    "llm_model_name": LLM_MODEL_NAME,
    "embedding_batch_num": 64,  # or another integer suitable for your setup
    "vector_db_storage_cls_kwargs": {
        "cosine_better_than_threshold": 0.2  # or another float threshold you want
    },
    "base_url": "https://api.openai.com/v1",
}

llm_cache = JsonKVStorage(namespace="llm_cache", global_config=kv_global_config, embedding_func=openai_embed)
    
async def llm_wrapper(prompt, history_messages=None, max_tokens=None, **kwargs):
    if history_messages is None:
        history_messages = []

    # Use Google GenAI
    return await gemini_complete_if_cache(
        model=LLM_MODEL_NAME,
        prompt=prompt,
        history_messages=history_messages,
        hashing_kv=llm_cache,
        temperature=0.2,
        max_tokens=max_tokens or 1024,
    )
# answer = dataset_loader["subtask1_batch2"].answer.tolist()[0]
# claim = dataset_loader["subtask1_batch2"].claim.tolist()[0]
# response = await preprocessing_claim(claim, answer, llm_wrapper, llm_cache, 1024, [])
# response

# %%
all_answer_batch_2 = dataset_loader["subtask1_batch2"].answer.tolist()
all_claim_batch_2 = dataset_loader["subtask1_batch2"].claim.tolist()

preprocess_path = "dataset/subtask1_train_batch2_preprocess.csv"
df = pd.read_csv(preprocess_path)
for index, (answer, claim) in enumerate(zip(all_answer_batch_2, all_claim_batch_2)):
    if index % 200 == 0:
        print(f"Processing index {index}")
    try:
        response = await preprocessing_claim(claim, answer, llm_wrapper, llm_cache, 1024, [])
        if response is None:
            print(f"Index {index} has no response")
            continue
        else:
            df.at[index, "claim"] = response
    except Exception as e:
        print(f"Index {index} has error")
        print(e)

df.to_csv(preprocess_path, index=False)

# %%
from pretty_prompt_compare import PrettyCompare

pretty_compare = PrettyCompare(compare_response=True, target=["they", "They", 
                                                              "them", "Them",
                                                              "their", "Their",
                                                              "theirs", "Theirs",
                                                              "them", "Them",
                                                              "these", "These",
                                                              "those", "Those",
                                                              "this", "This",
                                                              "that", "That",
                                                              "these", "These",
                                                              "those", "Those",
                                                              "this", "This"])

claim_processed = df.claim.tolist()
all_claim_batch_2 = dataset_loader["subtask1_batch2"].claim.tolist()

index = 21

all_claim_batch_2[index] |pretty_compare| claim_processed[index]

# %%
df.at[0, "claim"] = "2"
df.head()

# %%
#!/usr/bin/env python3

import os
import re
from datetime import datetime
from collections import defaultdict

def find_and_rename_newest_files_by_number():
    """
    Find the newest claim_batch2 files for each number (0-999) and rename them to claim_test format
    """
    outputs_dir = "outputs"
    
    # Pattern to match: claim_batch2_{number}_result_{timestamp}.pkl
    pattern = r'claim_batch2_(\d+)_result_(\d{8}_\d{6})\.(pkl|txt)'
    
    # Dictionary to store files by number, then by timestamp
    files_by_number = defaultdict(lambda: defaultdict(list))
    
    # Scan all files in outputs directory
    for filename in os.listdir(outputs_dir):
        match = re.match(pattern, filename)
        if match:
            number = match.group(1)
            timestamp = match.group(2)
            extension = match.group(3)
            
            files_by_number[number][timestamp].append({
                'filename': filename,
                'number': number,
                'timestamp': timestamp,
                'extension': extension,
                'full_path': os.path.join(outputs_dir, filename)
            })
    
    if not files_by_number:
        print("No files matching the pattern found!")
        return
    
    print(f"Found files for {len(files_by_number)} different numbers")
    
    # For each number, find the newest timestamp and rename those files
    renamed_count = 0
    numbers_processed = []
    
    for number in sorted(files_by_number.keys(), key=int):
        timestamps_for_number = files_by_number[number]
        
        # Find the newest timestamp for this number
        newest_timestamp = max(timestamps_for_number.keys())
        newest_files = timestamps_for_number[newest_timestamp]
        
        print(f"\nNumber {number}: Found {len(newest_files)} files with newest timestamp {newest_timestamp}")
        
        # Rename the files for this number
        for file_info in newest_files:
            old_path = file_info['full_path']
            
            # Create new filename: claim_test_result_{number}_{timestamp}.{extension}
            new_filename = f"claim_test_result_{file_info['number']}_{file_info['timestamp']}.{file_info['extension']}"
            new_path = os.path.join(outputs_dir, new_filename)
            
            try:
                os.rename(old_path, new_path)
                print(f"  Renamed: {file_info['filename']} -> {new_filename}")
                renamed_count += 1
            except Exception as e:
                print(f"  Error renaming {file_info['filename']}: {e}")
        
        numbers_processed.append(number)
    
    print(f"\nSuccessfully renamed {renamed_count} files for {len(numbers_processed)} different numbers!")
    
    # Show summary
    print(f"\nProcessed numbers: {', '.join(sorted(numbers_processed, key=int))}")
    
    # Show which numbers from 0-999 are missing
    all_numbers = set(str(i) for i in range(1000))
    found_numbers = set(files_by_number.keys())
    missing_numbers = all_numbers - found_numbers
    
    if missing_numbers:
        missing_sorted = sorted(missing_numbers, key=int)
        print(f"\nNumbers with no files found: {', '.join(missing_sorted[:20])}")
        if len(missing_numbers) > 20:
            print(f"... and {len(missing_numbers) - 20} more")


find_and_rename_newest_files_by_number()


find_and_rename_newest_files()

# %%
from utils import get_latest_result_by_prefix
index  = 0
claim_nodes, claim_edges = get_latest_result_by_prefix(f"claim_test_result_{index}_")

# %%
import os
import re

def rename_claim_test_files():
    """
    Rename files from claim_test_result_{number}_{timestamp}.{ext} 
    to claim_test_{number}_result_{timestamp}.{ext}
    """
    outputs_dir = "outputs"
    
    # Pattern to match: claim_test_result_{number}_{timestamp}.{extension}
    pattern = r'claim_test_result_(\d+)_(\d{8}_\d{6})\.(pkl|txt)'
    
    # Get all files in outputs directory
    files_to_rename = []
    
    for filename in os.listdir(outputs_dir):
        match = re.match(pattern, filename)
        if match:
            number = match.group(1)
            timestamp = match.group(2)
            extension = match.group(3)
            
            # Create new filename: claim_test_{number}_result_{timestamp}.{extension}
            new_filename = f"claim_test_{number}_result_{timestamp}.{extension}"
            
            files_to_rename.append({
                'old_filename': filename,
                'new_filename': new_filename,
                'old_path': os.path.join(outputs_dir, filename),
                'new_path': os.path.join(outputs_dir, new_filename)
            })
    
    if not files_to_rename:
        print("No files matching the pattern 'claim_test_result_*' found!")
        return
    
    print(f"Found {len(files_to_rename)} files to rename:")
    for file_info in files_to_rename:
        print(f"  {file_info['old_filename']} -> {file_info['new_filename']}")
    
    print(f"\nProceeding with renaming {len(files_to_rename)} files...")
    
    # Perform the renaming
    renamed_count = 0
    for file_info in files_to_rename:
        try:
            os.rename(file_info['old_path'], file_info['new_path'])
            print(f"✓ Renamed: {file_info['old_filename']} -> {file_info['new_filename']}")
            renamed_count += 1
        except Exception as e:
            print(f"✗ Error renaming {file_info['old_filename']}: {e}")
    
    print(f"\nSuccessfully renamed {renamed_count} out of {len(files_to_rename)} files!")

rename_claim_test_files()

# %%
from utils import get_latest_result_by_prefix

index = 1
claim_nodes, claim_edges = get_latest_result_by_prefix(f"claim_test_{index}_")

claim_nodes

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
import numpy as np
from kg_compare import get_src_tgt_dict, get_map_src_tgt_dict, find_best_span

from kg_compare import compare_knowledge_graphs_similarity, find_best_span_for_all_evidences
from utils import get_latest_result_by_prefix
import seaborn as sns

import numpy as np
from sklearn.cluster import KMeans
import os
all_responses = []

import pandas as pd

from geminillm import gemini_complete_if_cache
from json_kv_iml import JsonKVStorage
from operationCheatSheet import preprocessing_claim
from openaillm import openai_embed

# %%
from geminillm import gemini_complete_if_cache
from json_kv_iml import JsonKVStorage
from operationCheatSheet import preprocessing_claim
from openaillm import openai_embed

LLM_MODEL_NAME = "gemini-2.5-flash-preview-05-20"


kv_global_config = {
    "working_dir": "/tmp",
    "llm_model_name": LLM_MODEL_NAME,
    "embedding_batch_num": 64,  # or another integer suitable for your setup
    "vector_db_storage_cls_kwargs": {
        "cosine_better_than_threshold": 0.2  # or another float threshold you want
    },
    "base_url": "https://api.openai.com/v1",
}

llm_cache = JsonKVStorage(namespace="llm_cache", global_config=kv_global_config, embedding_func=openai_embed)
    
async def llm_wrapper(prompt, history_messages=None, max_tokens=None, **kwargs):
    if history_messages is None:
        history_messages = []

    # Use Google GenAI
    return await gemini_complete_if_cache(
        model=LLM_MODEL_NAME,
        prompt=prompt,
        history_messages=history_messages,
        hashing_kv=llm_cache,
        temperature=0.2,
        max_tokens=max_tokens or 10000,
    )
# answer = dataset_loader["subtask1_batch2"].answer.tolist()[0]
# claim = dataset_loader["subtask1_batch2"].claim.tolist()[0]
# response = await preprocessing_claim(claim, answer, llm_wrapper, llm_cache, 1024, [])
# response

# %%
TASKNAMES = ["subtask1", "subtask2"]
TYPES = ["test", "test_preprocess", "train_batch2", "train_batch2_preprocess"]

dataset_loader = dict()

for taskname in TASKNAMES:
    for type in TYPES:
        print(f"Processing {taskname} for {type}")
        prefix = "dataset"
        # Load the data
        
        if taskname == "subtask2" and type == "test_preprocess":
            continue
        if taskname == "subtask2" and type == "train_batch2_preprocess":
            continue
        data = pd.read_csv(f"{prefix}/{taskname}_{type}.csv")
        dataset_loader[f"{taskname}_{type}"] = data

dataset_loader["subtask1_test"]["claim"] = dataset_loader["subtask1_test_preprocess"]["claim"]
dataset_loader["subtask1_train_batch2"]["claim"] = dataset_loader["subtask1_train_batch2_preprocess"]["claim"]

output_file = "outputs/response_test.txt"
os.makedirs(os.path.dirname(output_file), exist_ok=True)
# Out:
# Processing subtask1 for test
# Processing subtask1 for test_preprocess
# Processing subtask1 for train_batch2
# Processing subtask1 for train_batch2_preprocess
# Processing subtask2 for test
# Processing subtask2 for test_preprocess
# Processing subtask2 for train_batch2
# Processing subtask2 for train_batch2_preprocess

# %%
LLM_MODEL_NAME = "gemini-2.5-flash-preview-05-20"
def write_prediction_to_file(index, row_id, prediction, output_file="outputs/response_test.txt"):
    """
    Write a line with row ID and prediction to the output file
    
    Args:
        row_id: The ID/index of the row being processed
        prediction: The prediction result
        output_file: Path to the output file
    """
    # Ensure outputs directory exists
    os.makedirs(os.path.dirname(output_file), exist_ok=True)
    
    # Write the prediction with row ID to file
    with open(output_file, 'a', encoding='utf-8') as f:
        f.write(f"{index}, {row_id}, {prediction}\n")

async def llm_wrapper(prompt, history_messages=None, max_tokens=None, **kwargs):
    if history_messages is None:
        history_messages = []


    # Use Google GenAI
    return await gemini_complete_if_cache(
        model=LLM_MODEL_NAME,
        prompt=prompt,
        history_messages=history_messages,
        hashing_kv=llm_cache,
        temperature=0.2,
        max_tokens=max_tokens or 1024,
    )

# %%
import os
import pandas as pd
import glob
from collections import Counter

folder_path = "outputs/kaggle_results/"

prefix = "response_clean"


# Step 1: Set up folder and file pattern
pattern = os.path.join(folder_path, f"{prefix}*.csv")
csv_files = glob.glob(pattern)

# Step 2: Identify main file and other files
main_file = [f for f in csv_files if 'jun26_1158' in f][0]
other_files = [f for f in csv_files if f != main_file]

# Step 2: Read and split "ID\tlabel" column into two columns: ID, label
dfs = []
def load_and_split(file):
    df = pd.read_csv(file)
    return df

dfs = [load_and_split(file) for file in csv_files]
main_df = load_and_split(main_file)
other_dfs = [load_and_split(file) for file in other_files]

# Step 4: Concatenate other files for majority voting
other_data = pd.concat(other_dfs)

# Step 5: Group by ID and get all labels (for checking if all disagree)
other_labels = other_data.groupby("ID")["label"].apply(list)

# Step 6: Merge with main_df to align labels
main_df = main_df.merge(other_labels, on="ID", how="left")  # Now has 'label_x' and 'label_y'

# Rename for clarity
main_df = main_df.rename(columns={"label_x": "main_label", "label_y": "other_labels"})

# Step 7: Apply conditional rule
def decide_label(row):
    main_label = row['main_label']
    other_votes = row['other_labels']
    if other_votes and all(label != main_label for label in other_votes):
        # Override with majority vote
        return Counter(other_votes).most_common(1)[0][0]
    else:
        return main_label

main_df['final_label'] = main_df.apply(decide_label, axis=1)

# Step 8: Build final result
final_df = main_df[['ID', 'final_label']].rename(columns={'final_label': 'label'})
best_df = pd.read_csv("outputs/kaggle_results/response_clean_jun26_1158.csv")
unver_list = [index for index in range(len(best_df)) if best_df.at[index, "label"] == "unver"]

# %%
# df_lora = pd.read_csv("outputs/kaggle_results/subtask1_submission_updated_lora.csv")

# df_best = best_df
# import pandas as pd
# from sklearn.metrics import confusion_matrix, classification_report
# import seaborn as sns
# import matplotlib.pyplot as plt

# # This code assumes 'df_best' and 'df_lora' are already loaded in your environment.
# # It also assumes they both have 'ID' and 'label' columns.

# try:
#     # Merge the dataframes on the 'ID' column to align them correctly for comparison.
#     # We rename the 'label' columns to avoid conflicts.
#     comparison_df = pd.merge(
#         df_best.rename(columns={'label': 'label_best'}), 
#         df_lora.rename(columns={'label': 'label_lora'}), 
#         on='ID'
#     )
    
#     label_col_best = 'label_best'
#     label_col_lora = 'label_lora'

#     # --- 1. Calculate and Print Difference Statistics ---
#     differences = comparison_df[label_col_best] != comparison_df[label_col_lora]
#     num_differences = differences.sum()
#     total_rows = len(comparison_df)
#     percentage_diff = (num_differences / total_rows) * 100 if total_rows > 0 else 0

#     print("Comparison of 'best' and 'lora' DataFrame Labels")
#     print("-" * 50)
#     print(f"Total common rows (by ID): {total_rows}")
#     print(f"Number of rows with different labels: {num_differences}")
#     print(f"Percentage of labels that are different: {percentage_diff:.2f}%")
#     print("-" * 50)

#     # --- 2. Show a Summary of Classification Changes ---
#     if num_differences > 0:
#         print("\nSummary of Classification Changes (from 'best' to 'lora'):\n")
#         # Creating a pivot table for a clear view of changes, e.g., how many 'entail' became 'contra'.
#         change_counts = comparison_df[differences].groupby([label_col_best, label_col_lora]).size().reset_index(name='counts')
#         print(change_counts.pivot_table(index=label_col_best, columns=label_col_lora, values='counts').fillna(0).astype(int))
#         print("-" * 50)

#     # --- 3. Generate a Detailed Classification Report ---
#     # This treats 'df_best' as the ground truth to evaluate 'df_lora'.
#     print("\nClassification Report (evaluating 'lora' against 'best'):\n")
#     print(classification_report(comparison_df[label_col_best], comparison_df[label_col_lora]))
#     print("-" * 50)

#     # --- 4. Display a Confusion Matrix ---
#     print("\nConfusion Matrix:\n")
#     # Get all unique labels present in either dataframe for the matrix axes.
#     all_labels = sorted(pd.unique(comparison_df[[label_col_best, label_col_lora]].values.ravel('K')))
    
#     conf_matrix = confusion_matrix(comparison_df[label_col_best], comparison_df[label_col_lora], labels=all_labels)

#     plt.figure(figsize=(8, 6))
#     sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
#                 xticklabels=all_labels, yticklabels=all_labels)
#     plt.title("Confusion Matrix: 'best' vs. 'lora' Classifications")
#     plt.ylabel("'best' DataFrame Label")
#     plt.xlabel("'lora' DataFrame Label")
#     plt.show()

# except KeyError as e:
#     print(f"Error: Could not find column {e}. Please ensure both DataFrames have an 'ID' and 'label' column.")
# except Exception as e:
#     print(f"An unexpected error occurred: {e}")

# %%
# # This code assumes 'comparison_df' (the merged dataframe) is available from a previous cell.

# def get_voted_label(row):
#     """
#     If the 'best' label is 'unver', return the 'lora' label.
#     Otherwise, keep the 'best' label.
#     """
#     if row['label_best'] == 'unver':
#         return row['label_lora']
#     else:
#         return row['label_best']

# # Apply the voting logic to create the final label column
# comparison_df['final_label'] = comparison_df.apply(get_voted_label, axis=1)

# # Create the final dataframe in the submission format ('ID', 'label')
# voted_df = comparison_df[['ID', 'final_label']].rename(columns={'final_label': 'label'})

# # --- Save the results to a new CSV file ---

# # Define the output path and ensure the directory exists
# output_path = "outputs/kaggle_results/voted_lora_jun28_1649.csv"
# import os
# os.makedirs(os.path.dirname(output_path), exist_ok=True)

# # Save the new dataframe to a CSV file, without the index
# voted_df.to_csv(output_path, index=False)

# # --- Display confirmation and results ---
# print(f"DataFrame successfully saved to: {output_path}")

# print("\nNew label distribution:")
# print(voted_df['label'].value_counts())

# print("\nFirst 5 rows of the new dataframe:")
# print(voted_df.head())

# %%
test_data = dataset_loader["subtask1_train_batch2"]

pickle_prefix = "batch2"
# pickle_prefix = "batch2"

for index in range(1000):
    if index % 50 == 0:
        print(f"Processing index {index}")
    
    row_id = test_data.at[index, "ID"]
    claim_content = test_data.at[index, "claim"]

    claim_nodes, claim_edges = await get_latest_result_by_prefix(f"claim_{pickle_prefix}_{index}_")
    reference_nodes, reference_edges = await get_latest_result_by_prefix(f"reference_{pickle_prefix}_{index}_")
    reference_content = test_data.at[index, "reference"]

    claim_node_list = list(claim_nodes.keys())
    reference_content = test_data.at[index, "reference"]
    
    prompt_template = f"""
    ### ROLE ###
    You are a specialized AI for factual information extraction. Your purpose is to distill information from a source text, focusing exclusively on a given list of entities. Your primary directive is absolute faithfulness to the source text.

    ### CORE DIRECTIVES (NON-NEGOTIABLE) ###
    You must adhere to the following rules without exception:

    1.  **Absolute Faithfulness:** Your output MUST be 100% derived from the provided 'Reference Text'. Do not add, infer, or assume any information that is not explicitly present in the text.

    2.  **Entity-Centric Focus:** The summary must ONLY describe information the reference provides about the entities from your list *that are actually mentioned in the text*. **Silently ignore** any entities from the list that are not found in the reference.

    3.  **Synthesize, Do Not Create:** You may rephrase and connect sentences for conciseness, but you must not create new facts or relationships that are not explicitly stated in the source.

    4.  **Handling No Matches:** If **none** of the entities from the list are found in the reference text, you MUST respond with the exact phrase: `No relevant information was found for the given entities.`

    5.  **Conciseness:** If information is available, the summary should be concise and direct, aiming for 2-4 sentences.

    ### YOUR TASK ###

    You are provided with a reference text and a list of entities. Generate a short, faithful summary based on the directives above.

    **Reference Text:**
    {reference_content}

    **Entities:**
    {claim_node_list}

    ### FAITHFUL SUMMARY ###
    """

    response = await llm_wrapper(prompt_template)
    all_responses.append(response)
    write_prediction_to_file(index, row_id, response)
# Out:
# Processing index 0
# Processing index 50
# Processing index 100
# No result files found with prefix 'reference_batch2_100_' in the outputs directory
# No result files found with prefix 'reference_batch2_101_' in the outputs directory
# No result files found with prefix 'reference_batch2_102_' in the outputs directory
# No result files found with prefix 'reference_batch2_103_' in the outputs directory
# No result files found with prefix 'reference_batch2_104_' in the outputs directory
# No result files found with prefix 'reference_batch2_105_' in the outputs directory
# No result files found with prefix 'reference_batch2_106_' in the outputs directory
# No result files found with prefix 'reference_batch2_107_' in the outputs directory
# No result files found with prefix 'reference_batch2_108_' in the outputs directory
# No result files found with prefix 'reference_batch2_109_' in the outputs directory
# No result files found with prefix 'reference_batch2_110_' in the outputs directory
# No result files found with prefix 'reference_batch2_111_' in the outputs directory
# No result files found with prefix 'reference_batch2_112_' in the outputs directory
# No result files found with prefix 'reference_batch2_113_' in the outputs directory
# No result files found with prefix 'reference_batch2_114_' in the outputs directory
# No result files found with prefix 'reference_batch2_115_' in the outputs directory
# No result files found with prefix 'reference_batch2_116_' in the outputs directory
# No result files found with prefix 'reference_batch2_117_' in the outputs directory
# No result files found with prefix 'reference_batch2_118_' in the outputs directory
# No result files found with prefix 'reference_batch2_119_' in the outputs directory
# No result files found with prefix 'reference_batch2_120_' in the outputs directory
# No result files found with prefix 'reference_batch2_121_' in the outputs directory
# No result files found with prefix 'reference_batch2_122_' in the outputs directory
# No result files found with prefix 'reference_batch2_123_' in the outputs directory
# No result files found with prefix 'reference_batch2_124_' in the outputs directory
# No result files found with prefix 'reference_batch2_125_' in the outputs directory
# No result files found with prefix 'reference_batch2_126_' in the outputs directory
# No result files found with prefix 'reference_batch2_127_' in the outputs directory
# No result files found with prefix 'reference_batch2_128_' in the outputs directory
# No result files found with prefix 'reference_batch2_129_' in the outputs directory
# No result files found with prefix 'reference_batch2_130_' in the outputs directory
# No result files found with prefix 'reference_batch2_131_' in the outputs directory
# No result files found with prefix 'reference_batch2_132_' in the outputs directory
# No result files found with prefix 'reference_batch2_133_' in the outputs directory
# No result files found with prefix 'reference_batch2_134_' in the outputs directory
# No result files found with prefix 'reference_batch2_135_' in the outputs directory
# No result files found with prefix 'reference_batch2_136_' in the outputs directory
# No result files found with prefix 'reference_batch2_137_' in the outputs directory
# No result files found with prefix 'reference_batch2_138_' in the outputs directory
# No result files found with prefix 'reference_batch2_139_' in the outputs directory
# No result files found with prefix 'reference_batch2_140_' in the outputs directory
# No result files found with prefix 'reference_batch2_141_' in the outputs directory
# No result files found with prefix 'reference_batch2_142_' in the outputs directory
# No result files found with prefix 'reference_batch2_143_' in the outputs directory
# No result files found with prefix 'reference_batch2_144_' in the outputs directory
# No result files found with prefix 'reference_batch2_145_' in the outputs directory
# No result files found with prefix 'reference_batch2_146_' in the outputs directory
# No result files found with prefix 'reference_batch2_147_' in the outputs directory
# No result files found with prefix 'reference_batch2_148_' in the outputs directory
# No result files found with prefix 'reference_batch2_149_' in the outputs directory
# Processing index 150
# No result files found with prefix 'reference_batch2_150_' in the outputs directory
# No result files found with prefix 'reference_batch2_151_' in the outputs directory
# No result files found with prefix 'reference_batch2_152_' in the outputs directory
# No result files found with prefix 'reference_batch2_153_' in the outputs directory
# No result files found with prefix 'reference_batch2_154_' in the outputs directory
# No result files found with prefix 'reference_batch2_155_' in the outputs directory
# No result files found with prefix 'reference_batch2_156_' in the outputs directory
# No result files found with prefix 'reference_batch2_157_' in the outputs directory
# No result files found with prefix 'reference_batch2_158_' in the outputs directory
# No result files found with prefix 'reference_batch2_159_' in the outputs directory
# No result files found with prefix 'reference_batch2_160_' in the outputs directory
# No result files found with prefix 'reference_batch2_161_' in the outputs directory
# No result files found with prefix 'reference_batch2_162_' in the outputs directory
# No result files found with prefix 'reference_batch2_163_' in the outputs directory
# No result files found with prefix 'reference_batch2_164_' in the outputs directory
# No result files found with prefix 'reference_batch2_165_' in the outputs directory
# No result files found with prefix 'reference_batch2_166_' in the outputs directory
# No result files found with prefix 'reference_batch2_167_' in the outputs directory
# No result files found with prefix 'reference_batch2_168_' in the outputs directory
# No result files found with prefix 'reference_batch2_169_' in the outputs directory
# No result files found with prefix 'reference_batch2_170_' in the outputs directory
# No result files found with prefix 'reference_batch2_171_' in the outputs directory
# No result files found with prefix 'reference_batch2_172_' in the outputs directory
# No result files found with prefix 'reference_batch2_173_' in the outputs directory
# No result files found with prefix 'reference_batch2_174_' in the outputs directory
# No result files found with prefix 'reference_batch2_175_' in the outputs directory
# No result files found with prefix 'reference_batch2_176_' in the outputs directory
# No result files found with prefix 'reference_batch2_177_' in the outputs directory
# No result files found with prefix 'reference_batch2_178_' in the outputs directory
# No result files found with prefix 'reference_batch2_179_' in the outputs directory
# No result files found with prefix 'reference_batch2_180_' in the outputs directory
# No result files found with prefix 'reference_batch2_181_' in the outputs directory
# No result files found with prefix 'reference_batch2_182_' in the outputs directory
# No result files found with prefix 'reference_batch2_183_' in the outputs directory
# No result files found with prefix 'reference_batch2_184_' in the outputs directory
# No result files found with prefix 'reference_batch2_185_' in the outputs directory
# No result files found with prefix 'reference_batch2_186_' in the outputs directory
# No result files found with prefix 'reference_batch2_187_' in the outputs directory
# No result files found with prefix 'reference_batch2_188_' in the outputs directory
# No result files found with prefix 'reference_batch2_189_' in the outputs directory
# No result files found with prefix 'reference_batch2_190_' in the outputs directory
# No result files found with prefix 'reference_batch2_191_' in the outputs directory
# No result files found with prefix 'reference_batch2_192_' in the outputs directory
# No result files found with prefix 'reference_batch2_193_' in the outputs directory
# No result files found with prefix 'reference_batch2_194_' in the outputs directory
# No result files found with prefix 'reference_batch2_195_' in the outputs directory
# No result files found with prefix 'reference_batch2_196_' in the outputs directory
# No result files found with prefix 'reference_batch2_197_' in the outputs directory
# No result files found with prefix 'reference_batch2_198_' in the outputs directory
# No result files found with prefix 'reference_batch2_199_' in the outputs directory
# Processing index 200
# No result files found with prefix 'reference_batch2_200_' in the outputs directory
# No result files found with prefix 'reference_batch2_201_' in the outputs directory
# No result files found with prefix 'reference_batch2_202_' in the outputs directory
# No result files found with prefix 'reference_batch2_203_' in the outputs directory
# No result files found with prefix 'reference_batch2_204_' in the outputs directory
# No result files found with prefix 'reference_batch2_205_' in the outputs directory
# No result files found with prefix 'reference_batch2_206_' in the outputs directory
# No result files found with prefix 'reference_batch2_207_' in the outputs directory
# No result files found with prefix 'reference_batch2_208_' in the outputs directory
# No result files found with prefix 'reference_batch2_209_' in the outputs directory
# No result files found with prefix 'reference_batch2_210_' in the outputs directory
# No result files found with prefix 'reference_batch2_211_' in the outputs directory
# No result files found with prefix 'reference_batch2_212_' in the outputs directory
# No result files found with prefix 'reference_batch2_213_' in the outputs directory
# No result files found with prefix 'reference_batch2_214_' in the outputs directory
# No result files found with prefix 'reference_batch2_215_' in the outputs directory
# No result files found with prefix 'reference_batch2_216_' in the outputs directory
# No result files found with prefix 'reference_batch2_217_' in the outputs directory
# No result files found with prefix 'reference_batch2_218_' in the outputs directory
# No result files found with prefix 'reference_batch2_219_' in the outputs directory
# No result files found with prefix 'reference_batch2_220_' in the outputs directory
# No result files found with prefix 'reference_batch2_221_' in the outputs directory
# No result files found with prefix 'reference_batch2_222_' in the outputs directory
# No result files found with prefix 'reference_batch2_223_' in the outputs directory
# No result files found with prefix 'reference_batch2_224_' in the outputs directory
# No result files found with prefix 'reference_batch2_225_' in the outputs directory
# No result files found with prefix 'reference_batch2_226_' in the outputs directory
# No result files found with prefix 'reference_batch2_227_' in the outputs directory
# No result files found with prefix 'reference_batch2_228_' in the outputs directory
# No result files found with prefix 'reference_batch2_229_' in the outputs directory
# No result files found with prefix 'reference_batch2_230_' in the outputs directory
# No result files found with prefix 'reference_batch2_231_' in the outputs directory
# No result files found with prefix 'reference_batch2_232_' in the outputs directory
# No result files found with prefix 'reference_batch2_233_' in the outputs directory
# No result files found with prefix 'reference_batch2_234_' in the outputs directory
# No result files found with prefix 'reference_batch2_235_' in the outputs directory
# No result files found with prefix 'reference_batch2_236_' in the outputs directory
# No result files found with prefix 'reference_batch2_237_' in the outputs directory
# No result files found with prefix 'reference_batch2_238_' in the outputs directory
# No result files found with prefix 'reference_batch2_239_' in the outputs directory
# No result files found with prefix 'reference_batch2_240_' in the outputs directory
# No result files found with prefix 'reference_batch2_241_' in the outputs directory
# No result files found with prefix 'reference_batch2_242_' in the outputs directory
# No result files found with prefix 'reference_batch2_243_' in the outputs directory
# No result files found with prefix 'reference_batch2_244_' in the outputs directory
# No result files found with prefix 'reference_batch2_245_' in the outputs directory
# No result files found with prefix 'reference_batch2_246_' in the outputs directory
# No result files found with prefix 'reference_batch2_247_' in the outputs directory
# No result files found with prefix 'reference_batch2_248_' in the outputs directory
# No result files found with prefix 'reference_batch2_249_' in the outputs directory
# Processing index 250
# No result files found with prefix 'reference_batch2_250_' in the outputs directory
# No result files found with prefix 'reference_batch2_251_' in the outputs directory
# No result files found with prefix 'reference_batch2_252_' in the outputs directory
# No result files found with prefix 'reference_batch2_253_' in the outputs directory
# No result files found with prefix 'reference_batch2_254_' in the outputs directory
# No result files found with prefix 'reference_batch2_255_' in the outputs directory
# No result files found with prefix 'reference_batch2_256_' in the outputs directory
# No result files found with prefix 'reference_batch2_257_' in the outputs directory
# No result files found with prefix 'reference_batch2_258_' in the outputs directory
# No result files found with prefix 'reference_batch2_259_' in the outputs directory
# No result files found with prefix 'reference_batch2_260_' in the outputs directory
# No result files found with prefix 'reference_batch2_261_' in the outputs directory
# No result files found with prefix 'reference_batch2_262_' in the outputs directory
# No result files found with prefix 'reference_batch2_263_' in the outputs directory
# No result files found with prefix 'reference_batch2_264_' in the outputs directory
# No result files found with prefix 'reference_batch2_265_' in the outputs directory
# No result files found with prefix 'reference_batch2_266_' in the outputs directory
# No result files found with prefix 'reference_batch2_267_' in the outputs directory
# No result files found with prefix 'reference_batch2_268_' in the outputs directory
# No result files found with prefix 'reference_batch2_269_' in the outputs directory
# No result files found with prefix 'reference_batch2_270_' in the outputs directory
# No result files found with prefix 'reference_batch2_271_' in the outputs directory
# No result files found with prefix 'reference_batch2_272_' in the outputs directory
# No result files found with prefix 'reference_batch2_273_' in the outputs directory
# No result files found with prefix 'reference_batch2_274_' in the outputs directory
# No result files found with prefix 'reference_batch2_275_' in the outputs directory
# No result files found with prefix 'reference_batch2_276_' in the outputs directory
# No result files found with prefix 'reference_batch2_277_' in the outputs directory
# No result files found with prefix 'reference_batch2_278_' in the outputs directory
# No result files found with prefix 'reference_batch2_279_' in the outputs directory
# No result files found with prefix 'reference_batch2_280_' in the outputs directory
# No result files found with prefix 'reference_batch2_281_' in the outputs directory
# No result files found with prefix 'reference_batch2_282_' in the outputs directory
# No result files found with prefix 'reference_batch2_283_' in the outputs directory
# No result files found with prefix 'reference_batch2_284_' in the outputs directory
# No result files found with prefix 'reference_batch2_285_' in the outputs directory
# No result files found with prefix 'reference_batch2_286_' in the outputs directory
# No result files found with prefix 'reference_batch2_287_' in the outputs directory
# No result files found with prefix 'reference_batch2_288_' in the outputs directory
# No result files found with prefix 'reference_batch2_289_' in the outputs directory
# No result files found with prefix 'reference_batch2_290_' in the outputs directory
# No result files found with prefix 'reference_batch2_291_' in the outputs directory
# No result files found with prefix 'reference_batch2_292_' in the outputs directory
# No result files found with prefix 'reference_batch2_293_' in the outputs directory
# No result files found with prefix 'reference_batch2_294_' in the outputs directory
# No result files found with prefix 'reference_batch2_295_' in the outputs directory
# No result files found with prefix 'reference_batch2_296_' in the outputs directory
# No result files found with prefix 'reference_batch2_297_' in the outputs directory
# No result files found with prefix 'reference_batch2_298_' in the outputs directory
# No result files found with prefix 'reference_batch2_299_' in the outputs directory
# Processing index 300
# No result files found with prefix 'reference_batch2_300_' in the outputs directory
# No result files found with prefix 'reference_batch2_301_' in the outputs directory
# No result files found with prefix 'reference_batch2_302_' in the outputs directory
# No result files found with prefix 'reference_batch2_303_' in the outputs directory
# No result files found with prefix 'reference_batch2_304_' in the outputs directory
# No result files found with prefix 'reference_batch2_305_' in the outputs directory
# No result files found with prefix 'reference_batch2_306_' in the outputs directory
# No result files found with prefix 'reference_batch2_307_' in the outputs directory
# No result files found with prefix 'reference_batch2_308_' in the outputs directory
# No result files found with prefix 'reference_batch2_309_' in the outputs directory
# No result files found with prefix 'reference_batch2_310_' in the outputs directory
# No result files found with prefix 'reference_batch2_311_' in the outputs directory
# No result files found with prefix 'reference_batch2_312_' in the outputs directory
# No result files found with prefix 'reference_batch2_313_' in the outputs directory
# No result files found with prefix 'reference_batch2_314_' in the outputs directory
# No result files found with prefix 'reference_batch2_315_' in the outputs directory
# No result files found with prefix 'reference_batch2_316_' in the outputs directory
# No result files found with prefix 'reference_batch2_317_' in the outputs directory
# No result files found with prefix 'reference_batch2_318_' in the outputs directory
# No result files found with prefix 'reference_batch2_319_' in the outputs directory
# No result files found with prefix 'reference_batch2_320_' in the outputs directory
# No result files found with prefix 'reference_batch2_321_' in the outputs directory
# No result files found with prefix 'reference_batch2_322_' in the outputs directory
# No result files found with prefix 'reference_batch2_323_' in the outputs directory
# No result files found with prefix 'reference_batch2_324_' in the outputs directory
# No result files found with prefix 'reference_batch2_325_' in the outputs directory
# No result files found with prefix 'reference_batch2_326_' in the outputs directory
# No result files found with prefix 'reference_batch2_327_' in the outputs directory
# No result files found with prefix 'reference_batch2_328_' in the outputs directory
# No result files found with prefix 'reference_batch2_329_' in the outputs directory
# No result files found with prefix 'reference_batch2_330_' in the outputs directory
# No result files found with prefix 'reference_batch2_331_' in the outputs directory
# No result files found with prefix 'reference_batch2_332_' in the outputs directory
# No result files found with prefix 'reference_batch2_333_' in the outputs directory
# No result files found with prefix 'reference_batch2_334_' in the outputs directory
# No result files found with prefix 'reference_batch2_335_' in the outputs directory
# No result files found with prefix 'reference_batch2_336_' in the outputs directory
# No result files found with prefix 'reference_batch2_337_' in the outputs directory
# No result files found with prefix 'reference_batch2_338_' in the outputs directory
# No result files found with prefix 'reference_batch2_339_' in the outputs directory
# No result files found with prefix 'reference_batch2_340_' in the outputs directory
# No result files found with prefix 'reference_batch2_341_' in the outputs directory
# No result files found with prefix 'reference_batch2_342_' in the outputs directory
# No result files found with prefix 'reference_batch2_343_' in the outputs directory
# No result files found with prefix 'reference_batch2_344_' in the outputs directory
# No result files found with prefix 'reference_batch2_345_' in the outputs directory
# No result files found with prefix 'reference_batch2_346_' in the outputs directory
# No result files found with prefix 'reference_batch2_347_' in the outputs directory
# No result files found with prefix 'reference_batch2_348_' in the outputs directory
# No result files found with prefix 'reference_batch2_349_' in the outputs directory
# Processing index 350
# No result files found with prefix 'reference_batch2_350_' in the outputs directory
# No result files found with prefix 'reference_batch2_351_' in the outputs directory
# No result files found with prefix 'reference_batch2_352_' in the outputs directory
# No result files found with prefix 'reference_batch2_353_' in the outputs directory
# No result files found with prefix 'reference_batch2_354_' in the outputs directory
# No result files found with prefix 'reference_batch2_355_' in the outputs directory
# No result files found with prefix 'reference_batch2_356_' in the outputs directory
# No result files found with prefix 'reference_batch2_357_' in the outputs directory
# No result files found with prefix 'reference_batch2_358_' in the outputs directory
# No result files found with prefix 'reference_batch2_359_' in the outputs directory
# No result files found with prefix 'reference_batch2_360_' in the outputs directory
# No result files found with prefix 'reference_batch2_361_' in the outputs directory
# No result files found with prefix 'reference_batch2_362_' in the outputs directory
# No result files found with prefix 'reference_batch2_363_' in the outputs directory
# No result files found with prefix 'reference_batch2_364_' in the outputs directory
# No result files found with prefix 'reference_batch2_365_' in the outputs directory
# No result files found with prefix 'reference_batch2_366_' in the outputs directory
# No result files found with prefix 'reference_batch2_367_' in the outputs directory
# No result files found with prefix 'reference_batch2_368_' in the outputs directory
# No result files found with prefix 'reference_batch2_369_' in the outputs directory
# No result files found with prefix 'reference_batch2_370_' in the outputs directory
# No result files found with prefix 'reference_batch2_371_' in the outputs directory
# No result files found with prefix 'reference_batch2_372_' in the outputs directory
# No result files found with prefix 'reference_batch2_373_' in the outputs directory
# No result files found with prefix 'reference_batch2_374_' in the outputs directory
# No result files found with prefix 'reference_batch2_375_' in the outputs directory
# No result files found with prefix 'reference_batch2_376_' in the outputs directory
# No result files found with prefix 'reference_batch2_377_' in the outputs directory
# No result files found with prefix 'reference_batch2_378_' in the outputs directory
# No result files found with prefix 'reference_batch2_379_' in the outputs directory
# No result files found with prefix 'reference_batch2_380_' in the outputs directory
# No result files found with prefix 'reference_batch2_381_' in the outputs directory
# No result files found with prefix 'reference_batch2_382_' in the outputs directory
# No result files found with prefix 'reference_batch2_383_' in the outputs directory
# No result files found with prefix 'reference_batch2_384_' in the outputs directory
# No result files found with prefix 'reference_batch2_385_' in the outputs directory
# No result files found with prefix 'reference_batch2_386_' in the outputs directory
# No result files found with prefix 'reference_batch2_387_' in the outputs directory
# No result files found with prefix 'reference_batch2_388_' in the outputs directory
# No result files found with prefix 'reference_batch2_389_' in the outputs directory
# No result files found with prefix 'reference_batch2_390_' in the outputs directory
# No result files found with prefix 'reference_batch2_391_' in the outputs directory
# No result files found with prefix 'reference_batch2_392_' in the outputs directory
# No result files found with prefix 'reference_batch2_393_' in the outputs directory
# No result files found with prefix 'reference_batch2_394_' in the outputs directory
# No result files found with prefix 'reference_batch2_395_' in the outputs directory
# No result files found with prefix 'reference_batch2_396_' in the outputs directory
# No result files found with prefix 'reference_batch2_397_' in the outputs directory
# No result files found with prefix 'reference_batch2_398_' in the outputs directory
# No result files found with prefix 'reference_batch2_399_' in the outputs directory
# Processing index 400
# No result files found with prefix 'reference_batch2_400_' in the outputs directory
# No result files found with prefix 'reference_batch2_401_' in the outputs directory
# No result files found with prefix 'reference_batch2_402_' in the outputs directory
# No result files found with prefix 'reference_batch2_403_' in the outputs directory
# No result files found with prefix 'reference_batch2_404_' in the outputs directory
# No result files found with prefix 'reference_batch2_405_' in the outputs directory
# No result files found with prefix 'reference_batch2_406_' in the outputs directory
# No result files found with prefix 'reference_batch2_407_' in the outputs directory
# No result files found with prefix 'reference_batch2_408_' in the outputs directory
# No result files found with prefix 'reference_batch2_409_' in the outputs directory
# No result files found with prefix 'reference_batch2_410_' in the outputs directory
# No result files found with prefix 'reference_batch2_411_' in the outputs directory
# No result files found with prefix 'reference_batch2_412_' in the outputs directory
# No result files found with prefix 'reference_batch2_413_' in the outputs directory
# No result files found with prefix 'reference_batch2_414_' in the outputs directory
# No result files found with prefix 'reference_batch2_415_' in the outputs directory
# No result files found with prefix 'reference_batch2_416_' in the outputs directory
# No result files found with prefix 'reference_batch2_417_' in the outputs directory
# No result files found with prefix 'reference_batch2_418_' in the outputs directory
# No result files found with prefix 'reference_batch2_419_' in the outputs directory
# No result files found with prefix 'reference_batch2_420_' in the outputs directory
# No result files found with prefix 'reference_batch2_421_' in the outputs directory
# No result files found with prefix 'reference_batch2_422_' in the outputs directory
# No result files found with prefix 'reference_batch2_423_' in the outputs directory
# No result files found with prefix 'reference_batch2_424_' in the outputs directory
# No result files found with prefix 'reference_batch2_425_' in the outputs directory
# No result files found with prefix 'reference_batch2_426_' in the outputs directory
# No result files found with prefix 'reference_batch2_427_' in the outputs directory
# No result files found with prefix 'reference_batch2_428_' in the outputs directory
# No result files found with prefix 'reference_batch2_429_' in the outputs directory
# No result files found with prefix 'reference_batch2_430_' in the outputs directory
# No result files found with prefix 'reference_batch2_431_' in the outputs directory
# No result files found with prefix 'reference_batch2_432_' in the outputs directory
# No result files found with prefix 'reference_batch2_433_' in the outputs directory
# No result files found with prefix 'reference_batch2_434_' in the outputs directory
# No result files found with prefix 'reference_batch2_435_' in the outputs directory
# No result files found with prefix 'reference_batch2_436_' in the outputs directory
# No result files found with prefix 'reference_batch2_437_' in the outputs directory
# No result files found with prefix 'reference_batch2_438_' in the outputs directory
# No result files found with prefix 'reference_batch2_439_' in the outputs directory
# No result files found with prefix 'reference_batch2_440_' in the outputs directory
# No result files found with prefix 'reference_batch2_441_' in the outputs directory
# No result files found with prefix 'reference_batch2_442_' in the outputs directory
# No result files found with prefix 'reference_batch2_443_' in the outputs directory
# No result files found with prefix 'reference_batch2_444_' in the outputs directory
# No result files found with prefix 'reference_batch2_445_' in the outputs directory
# No result files found with prefix 'reference_batch2_446_' in the outputs directory
# No result files found with prefix 'reference_batch2_447_' in the outputs directory
# No result files found with prefix 'reference_batch2_448_' in the outputs directory
# No result files found with prefix 'reference_batch2_449_' in the outputs directory
# Processing index 450
# No result files found with prefix 'reference_batch2_450_' in the outputs directory
# No result files found with prefix 'reference_batch2_451_' in the outputs directory
# No result files found with prefix 'reference_batch2_452_' in the outputs directory
# No result files found with prefix 'reference_batch2_453_' in the outputs directory
# No result files found with prefix 'reference_batch2_454_' in the outputs directory
# No result files found with prefix 'reference_batch2_455_' in the outputs directory
# No result files found with prefix 'reference_batch2_456_' in the outputs directory
# No result files found with prefix 'reference_batch2_457_' in the outputs directory
# No result files found with prefix 'reference_batch2_458_' in the outputs directory
# No result files found with prefix 'reference_batch2_459_' in the outputs directory
# No result files found with prefix 'reference_batch2_460_' in the outputs directory
# No result files found with prefix 'reference_batch2_461_' in the outputs directory
# No result files found with prefix 'reference_batch2_462_' in the outputs directory
# No result files found with prefix 'reference_batch2_463_' in the outputs directory
# No result files found with prefix 'reference_batch2_464_' in the outputs directory
# No result files found with prefix 'reference_batch2_465_' in the outputs directory
# No result files found with prefix 'reference_batch2_466_' in the outputs directory
# No result files found with prefix 'reference_batch2_467_' in the outputs directory
# No result files found with prefix 'reference_batch2_468_' in the outputs directory
# No result files found with prefix 'reference_batch2_469_' in the outputs directory
# No result files found with prefix 'reference_batch2_470_' in the outputs directory
# No result files found with prefix 'reference_batch2_471_' in the outputs directory
# No result files found with prefix 'reference_batch2_472_' in the outputs directory
# No result files found with prefix 'reference_batch2_473_' in the outputs directory
# No result files found with prefix 'reference_batch2_474_' in the outputs directory
# No result files found with prefix 'reference_batch2_475_' in the outputs directory
# No result files found with prefix 'reference_batch2_476_' in the outputs directory
# No result files found with prefix 'reference_batch2_477_' in the outputs directory
# No result files found with prefix 'reference_batch2_478_' in the outputs directory
# No result files found with prefix 'reference_batch2_479_' in the outputs directory
# No result files found with prefix 'reference_batch2_480_' in the outputs directory
# No result files found with prefix 'reference_batch2_481_' in the outputs directory
# No result files found with prefix 'reference_batch2_482_' in the outputs directory
# No result files found with prefix 'reference_batch2_483_' in the outputs directory
# No result files found with prefix 'reference_batch2_484_' in the outputs directory
# No result files found with prefix 'reference_batch2_485_' in the outputs directory
# No result files found with prefix 'reference_batch2_486_' in the outputs directory
# No result files found with prefix 'reference_batch2_487_' in the outputs directory
# No result files found with prefix 'reference_batch2_488_' in the outputs directory
# No result files found with prefix 'reference_batch2_489_' in the outputs directory
# No result files found with prefix 'reference_batch2_490_' in the outputs directory
# No result files found with prefix 'reference_batch2_491_' in the outputs directory
# No result files found with prefix 'reference_batch2_492_' in the outputs directory
# No result files found with prefix 'reference_batch2_493_' in the outputs directory
# No result files found with prefix 'reference_batch2_494_' in the outputs directory
# No result files found with prefix 'reference_batch2_495_' in the outputs directory
# No result files found with prefix 'reference_batch2_496_' in the outputs directory
# No result files found with prefix 'reference_batch2_497_' in the outputs directory
# No result files found with prefix 'reference_batch2_498_' in the outputs directory
# No result files found with prefix 'reference_batch2_499_' in the outputs directory
# Processing index 500
# No result files found with prefix 'reference_batch2_500_' in the outputs directory
# No result files found with prefix 'reference_batch2_501_' in the outputs directory
# No result files found with prefix 'reference_batch2_502_' in the outputs directory
# No result files found with prefix 'reference_batch2_503_' in the outputs directory
# No result files found with prefix 'reference_batch2_504_' in the outputs directory
# No result files found with prefix 'reference_batch2_505_' in the outputs directory
# No result files found with prefix 'reference_batch2_506_' in the outputs directory
# No result files found with prefix 'reference_batch2_507_' in the outputs directory
# No result files found with prefix 'reference_batch2_508_' in the outputs directory
# No result files found with prefix 'reference_batch2_509_' in the outputs directory
# No result files found with prefix 'reference_batch2_510_' in the outputs directory
# No result files found with prefix 'reference_batch2_511_' in the outputs directory
# No result files found with prefix 'reference_batch2_512_' in the outputs directory
# No result files found with prefix 'reference_batch2_513_' in the outputs directory
# No result files found with prefix 'reference_batch2_514_' in the outputs directory
# No result files found with prefix 'reference_batch2_515_' in the outputs directory
# No result files found with prefix 'reference_batch2_516_' in the outputs directory
# No result files found with prefix 'reference_batch2_517_' in the outputs directory
# No result files found with prefix 'reference_batch2_518_' in the outputs directory
# No result files found with prefix 'reference_batch2_519_' in the outputs directory
# No result files found with prefix 'reference_batch2_520_' in the outputs directory
# No result files found with prefix 'reference_batch2_521_' in the outputs directory
# No result files found with prefix 'reference_batch2_522_' in the outputs directory
# No result files found with prefix 'reference_batch2_523_' in the outputs directory
# No result files found with prefix 'reference_batch2_524_' in the outputs directory
# No result files found with prefix 'reference_batch2_525_' in the outputs directory
# No result files found with prefix 'reference_batch2_526_' in the outputs directory
# No result files found with prefix 'reference_batch2_527_' in the outputs directory
# No result files found with prefix 'reference_batch2_528_' in the outputs directory
# No result files found with prefix 'reference_batch2_529_' in the outputs directory
# No result files found with prefix 'reference_batch2_530_' in the outputs directory
# No result files found with prefix 'reference_batch2_531_' in the outputs directory
# No result files found with prefix 'reference_batch2_532_' in the outputs directory
# No result files found with prefix 'reference_batch2_533_' in the outputs directory
# No result files found with prefix 'reference_batch2_534_' in the outputs directory
# No result files found with prefix 'reference_batch2_535_' in the outputs directory
# No result files found with prefix 'reference_batch2_536_' in the outputs directory
# No result files found with prefix 'reference_batch2_537_' in the outputs directory
# No result files found with prefix 'reference_batch2_538_' in the outputs directory
# No result files found with prefix 'reference_batch2_539_' in the outputs directory
# No result files found with prefix 'reference_batch2_540_' in the outputs directory
# No result files found with prefix 'reference_batch2_541_' in the outputs directory
# No result files found with prefix 'reference_batch2_542_' in the outputs directory
# No result files found with prefix 'reference_batch2_543_' in the outputs directory
# No result files found with prefix 'reference_batch2_544_' in the outputs directory
# No result files found with prefix 'reference_batch2_545_' in the outputs directory
# No result files found with prefix 'reference_batch2_546_' in the outputs directory
# No result files found with prefix 'reference_batch2_547_' in the outputs directory
# No result files found with prefix 'reference_batch2_548_' in the outputs directory
# No result files found with prefix 'reference_batch2_549_' in the outputs directory
# Processing index 550
# No result files found with prefix 'reference_batch2_550_' in the outputs directory
# No result files found with prefix 'reference_batch2_551_' in the outputs directory
# No result files found with prefix 'reference_batch2_552_' in the outputs directory
# No result files found with prefix 'reference_batch2_553_' in the outputs directory
# No result files found with prefix 'reference_batch2_554_' in the outputs directory
# No result files found with prefix 'reference_batch2_555_' in the outputs directory
# No result files found with prefix 'reference_batch2_556_' in the outputs directory
# No result files found with prefix 'reference_batch2_557_' in the outputs directory
# No result files found with prefix 'reference_batch2_558_' in the outputs directory
# No result files found with prefix 'reference_batch2_559_' in the outputs directory
# No result files found with prefix 'reference_batch2_560_' in the outputs directory
# No result files found with prefix 'reference_batch2_561_' in the outputs directory
# No result files found with prefix 'reference_batch2_562_' in the outputs directory
# No result files found with prefix 'reference_batch2_563_' in the outputs directory
# No result files found with prefix 'reference_batch2_564_' in the outputs directory
# No result files found with prefix 'reference_batch2_565_' in the outputs directory
# No result files found with prefix 'reference_batch2_566_' in the outputs directory
# No result files found with prefix 'reference_batch2_567_' in the outputs directory
# No result files found with prefix 'reference_batch2_568_' in the outputs directory
# No result files found with prefix 'reference_batch2_569_' in the outputs directory
# No result files found with prefix 'reference_batch2_570_' in the outputs directory
# No result files found with prefix 'reference_batch2_571_' in the outputs directory
# No result files found with prefix 'reference_batch2_572_' in the outputs directory
# No result files found with prefix 'reference_batch2_573_' in the outputs directory
# No result files found with prefix 'reference_batch2_574_' in the outputs directory
# No result files found with prefix 'reference_batch2_575_' in the outputs directory
# No result files found with prefix 'reference_batch2_576_' in the outputs directory
# No result files found with prefix 'reference_batch2_577_' in the outputs directory
# No result files found with prefix 'reference_batch2_578_' in the outputs directory
# No result files found with prefix 'reference_batch2_579_' in the outputs directory
# No result files found with prefix 'reference_batch2_580_' in the outputs directory
# No result files found with prefix 'reference_batch2_581_' in the outputs directory
# No result files found with prefix 'reference_batch2_582_' in the outputs directory
# No result files found with prefix 'reference_batch2_583_' in the outputs directory
# No result files found with prefix 'reference_batch2_584_' in the outputs directory
# No result files found with prefix 'reference_batch2_585_' in the outputs directory
# No result files found with prefix 'reference_batch2_586_' in the outputs directory
# No result files found with prefix 'reference_batch2_587_' in the outputs directory
# No result files found with prefix 'reference_batch2_588_' in the outputs directory
# No result files found with prefix 'reference_batch2_589_' in the outputs directory
# No result files found with prefix 'reference_batch2_590_' in the outputs directory
# No result files found with prefix 'reference_batch2_591_' in the outputs directory
# No result files found with prefix 'reference_batch2_592_' in the outputs directory
# No result files found with prefix 'reference_batch2_593_' in the outputs directory
# No result files found with prefix 'reference_batch2_594_' in the outputs directory
# No result files found with prefix 'reference_batch2_595_' in the outputs directory
# No result files found with prefix 'reference_batch2_596_' in the outputs directory
# No result files found with prefix 'reference_batch2_597_' in the outputs directory
# No result files found with prefix 'reference_batch2_598_' in the outputs directory
# No result files found with prefix 'reference_batch2_599_' in the outputs directory
# Processing index 600
# No result files found with prefix 'reference_batch2_600_' in the outputs directory
# No result files found with prefix 'reference_batch2_601_' in the outputs directory
# No result files found with prefix 'reference_batch2_602_' in the outputs directory
# No result files found with prefix 'reference_batch2_603_' in the outputs directory
# No result files found with prefix 'reference_batch2_604_' in the outputs directory
# No result files found with prefix 'reference_batch2_605_' in the outputs directory
# No result files found with prefix 'reference_batch2_606_' in the outputs directory
# No result files found with prefix 'reference_batch2_607_' in the outputs directory
# No result files found with prefix 'reference_batch2_608_' in the outputs directory
# No result files found with prefix 'reference_batch2_609_' in the outputs directory
# No result files found with prefix 'reference_batch2_610_' in the outputs directory
# No result files found with prefix 'reference_batch2_611_' in the outputs directory
# No result files found with prefix 'reference_batch2_612_' in the outputs directory
# No result files found with prefix 'reference_batch2_613_' in the outputs directory
# No result files found with prefix 'reference_batch2_614_' in the outputs directory
# No result files found with prefix 'reference_batch2_615_' in the outputs directory
# No result files found with prefix 'reference_batch2_616_' in the outputs directory
# No result files found with prefix 'reference_batch2_617_' in the outputs directory
# No result files found with prefix 'reference_batch2_618_' in the outputs directory
# No result files found with prefix 'reference_batch2_619_' in the outputs directory
# No result files found with prefix 'reference_batch2_620_' in the outputs directory
# No result files found with prefix 'reference_batch2_621_' in the outputs directory
# No result files found with prefix 'reference_batch2_622_' in the outputs directory
# No result files found with prefix 'reference_batch2_623_' in the outputs directory
# No result files found with prefix 'reference_batch2_624_' in the outputs directory
# No result files found with prefix 'reference_batch2_625_' in the outputs directory
# No result files found with prefix 'reference_batch2_626_' in the outputs directory
# No result files found with prefix 'reference_batch2_627_' in the outputs directory
# No result files found with prefix 'reference_batch2_628_' in the outputs directory
# No result files found with prefix 'reference_batch2_629_' in the outputs directory
# No result files found with prefix 'reference_batch2_630_' in the outputs directory
# No result files found with prefix 'reference_batch2_631_' in the outputs directory
# No result files found with prefix 'reference_batch2_632_' in the outputs directory
# No result files found with prefix 'reference_batch2_633_' in the outputs directory
# No result files found with prefix 'reference_batch2_634_' in the outputs directory
# No result files found with prefix 'reference_batch2_635_' in the outputs directory
# No result files found with prefix 'reference_batch2_636_' in the outputs directory
# No result files found with prefix 'reference_batch2_637_' in the outputs directory
# No result files found with prefix 'reference_batch2_638_' in the outputs directory
# No result files found with prefix 'reference_batch2_639_' in the outputs directory
# No result files found with prefix 'reference_batch2_640_' in the outputs directory
# No result files found with prefix 'reference_batch2_641_' in the outputs directory
# No result files found with prefix 'reference_batch2_642_' in the outputs directory
# No result files found with prefix 'reference_batch2_643_' in the outputs directory
# No result files found with prefix 'reference_batch2_644_' in the outputs directory
# No result files found with prefix 'reference_batch2_645_' in the outputs directory
# No result files found with prefix 'reference_batch2_646_' in the outputs directory
# No result files found with prefix 'reference_batch2_647_' in the outputs directory
# No result files found with prefix 'reference_batch2_648_' in the outputs directory
# No result files found with prefix 'reference_batch2_649_' in the outputs directory
# Processing index 650
# No result files found with prefix 'reference_batch2_650_' in the outputs directory
# No result files found with prefix 'reference_batch2_651_' in the outputs directory
# No result files found with prefix 'reference_batch2_652_' in the outputs directory
# No result files found with prefix 'reference_batch2_653_' in the outputs directory
# No result files found with prefix 'reference_batch2_654_' in the outputs directory
# No result files found with prefix 'reference_batch2_655_' in the outputs directory
# No result files found with prefix 'reference_batch2_656_' in the outputs directory
# No result files found with prefix 'reference_batch2_657_' in the outputs directory
# No result files found with prefix 'reference_batch2_658_' in the outputs directory
# No result files found with prefix 'reference_batch2_659_' in the outputs directory
# No result files found with prefix 'reference_batch2_660_' in the outputs directory
# No result files found with prefix 'reference_batch2_661_' in the outputs directory
# No result files found with prefix 'reference_batch2_662_' in the outputs directory
# No result files found with prefix 'reference_batch2_663_' in the outputs directory
# No result files found with prefix 'reference_batch2_664_' in the outputs directory
# No result files found with prefix 'reference_batch2_665_' in the outputs directory
# No result files found with prefix 'reference_batch2_666_' in the outputs directory
# No result files found with prefix 'reference_batch2_667_' in the outputs directory
# No result files found with prefix 'reference_batch2_668_' in the outputs directory
# No result files found with prefix 'reference_batch2_669_' in the outputs directory
# No result files found with prefix 'reference_batch2_670_' in the outputs directory
# No result files found with prefix 'reference_batch2_671_' in the outputs directory
# No result files found with prefix 'reference_batch2_672_' in the outputs directory
# No result files found with prefix 'reference_batch2_673_' in the outputs directory
# ...
# No result files found with prefix 'reference_batch2_808_' in the outputs directory
# No result files found with prefix 'reference_batch2_809_' in the outputs directory
# No result files found with prefix 'reference_batch2_810_' in the outputs directory
# No result files found with prefix 'reference_batch2_811_' in the outputs directory
# No result files found with prefix 'reference_batch2_812_' in the outputs directory
# No result files found with prefix 'reference_batch2_813_' in the outputs directory
# No result files found with prefix 'reference_batch2_814_' in the outputs directory
# No result files found with prefix 'reference_batch2_815_' in the outputs directory
# No result files found with prefix 'reference_batch2_816_' in the outputs directory
# No result files found with prefix 'reference_batch2_817_' in the outputs directory
# No result files found with prefix 'reference_batch2_818_' in the outputs directory
# No result files found with prefix 'reference_batch2_819_' in the outputs directory
# No result files found with prefix 'reference_batch2_820_' in the outputs directory
# No result files found with prefix 'reference_batch2_821_' in the outputs directory
# No result files found with prefix 'reference_batch2_822_' in the outputs directory
# No result files found with prefix 'reference_batch2_823_' in the outputs directory
# No result files found with prefix 'reference_batch2_824_' in the outputs directory
# No result files found with prefix 'reference_batch2_825_' in the outputs directory
# No result files found with prefix 'reference_batch2_826_' in the outputs directory
# No result files found with prefix 'reference_batch2_827_' in the outputs directory
# No result files found with prefix 'reference_batch2_828_' in the outputs directory
# No result files found with prefix 'reference_batch2_829_' in the outputs directory
# No result files found with prefix 'reference_batch2_830_' in the outputs directory
# No result files found with prefix 'reference_batch2_831_' in the outputs directory
# No result files found with prefix 'reference_batch2_832_' in the outputs directory
# No result files found with prefix 'reference_batch2_833_' in the outputs directory
# No result files found with prefix 'reference_batch2_834_' in the outputs directory
# No result files found with prefix 'reference_batch2_835_' in the outputs directory
# No result files found with prefix 'reference_batch2_836_' in the outputs directory
# No result files found with prefix 'reference_batch2_837_' in the outputs directory
# No result files found with prefix 'reference_batch2_838_' in the outputs directory
# No result files found with prefix 'reference_batch2_839_' in the outputs directory
# No result files found with prefix 'reference_batch2_840_' in the outputs directory
# No result files found with prefix 'reference_batch2_841_' in the outputs directory
# No result files found with prefix 'reference_batch2_842_' in the outputs directory
# No result files found with prefix 'reference_batch2_843_' in the outputs directory
# No result files found with prefix 'reference_batch2_844_' in the outputs directory
# No result files found with prefix 'reference_batch2_845_' in the outputs directory
# No result files found with prefix 'reference_batch2_846_' in the outputs directory
# No result files found with prefix 'reference_batch2_847_' in the outputs directory
# No result files found with prefix 'reference_batch2_848_' in the outputs directory
# No result files found with prefix 'reference_batch2_849_' in the outputs directory
# Processing index 850
# No result files found with prefix 'reference_batch2_850_' in the outputs directory
# No result files found with prefix 'reference_batch2_851_' in the outputs directory
# No result files found with prefix 'reference_batch2_852_' in the outputs directory
# No result files found with prefix 'reference_batch2_853_' in the outputs directory
# No result files found with prefix 'reference_batch2_854_' in the outputs directory
# No result files found with prefix 'reference_batch2_855_' in the outputs directory
# No result files found with prefix 'reference_batch2_856_' in the outputs directory
# No result files found with prefix 'reference_batch2_857_' in the outputs directory
# No result files found with prefix 'reference_batch2_858_' in the outputs directory
# No result files found with prefix 'reference_batch2_859_' in the outputs directory
# No result files found with prefix 'reference_batch2_860_' in the outputs directory
# No result files found with prefix 'reference_batch2_861_' in the outputs directory
# No result files found with prefix 'reference_batch2_862_' in the outputs directory
# No result files found with prefix 'reference_batch2_863_' in the outputs directory
# No result files found with prefix 'reference_batch2_864_' in the outputs directory
# No result files found with prefix 'reference_batch2_865_' in the outputs directory
# No result files found with prefix 'reference_batch2_866_' in the outputs directory
# No result files found with prefix 'reference_batch2_867_' in the outputs directory
# No result files found with prefix 'reference_batch2_868_' in the outputs directory
# No result files found with prefix 'reference_batch2_869_' in the outputs directory
# No result files found with prefix 'reference_batch2_870_' in the outputs directory
# No result files found with prefix 'reference_batch2_871_' in the outputs directory
# No result files found with prefix 'reference_batch2_872_' in the outputs directory
# No result files found with prefix 'reference_batch2_873_' in the outputs directory
# No result files found with prefix 'reference_batch2_874_' in the outputs directory
# No result files found with prefix 'reference_batch2_875_' in the outputs directory
# No result files found with prefix 'reference_batch2_876_' in the outputs directory
# No result files found with prefix 'reference_batch2_877_' in the outputs directory
# No result files found with prefix 'reference_batch2_878_' in the outputs directory
# No result files found with prefix 'reference_batch2_879_' in the outputs directory
# No result files found with prefix 'reference_batch2_880_' in the outputs directory
# No result files found with prefix 'reference_batch2_881_' in the outputs directory
# No result files found with prefix 'reference_batch2_882_' in the outputs directory
# No result files found with prefix 'reference_batch2_883_' in the outputs directory
# No result files found with prefix 'reference_batch2_884_' in the outputs directory
# No result files found with prefix 'reference_batch2_885_' in the outputs directory
# No result files found with prefix 'reference_batch2_886_' in the outputs directory
# No result files found with prefix 'reference_batch2_887_' in the outputs directory
# No result files found with prefix 'reference_batch2_888_' in the outputs directory
# No result files found with prefix 'reference_batch2_889_' in the outputs directory
# No result files found with prefix 'reference_batch2_890_' in the outputs directory
# No result files found with prefix 'reference_batch2_891_' in the outputs directory
# No result files found with prefix 'reference_batch2_892_' in the outputs directory
# No result files found with prefix 'reference_batch2_893_' in the outputs directory
# No result files found with prefix 'reference_batch2_894_' in the outputs directory
# No result files found with prefix 'reference_batch2_895_' in the outputs directory
# No result files found with prefix 'reference_batch2_896_' in the outputs directory
# No result files found with prefix 'reference_batch2_897_' in the outputs directory
# No result files found with prefix 'reference_batch2_898_' in the outputs directory
# No result files found with prefix 'reference_batch2_899_' in the outputs directory
# Processing index 900
# No result files found with prefix 'reference_batch2_900_' in the outputs directory
# No result files found with prefix 'reference_batch2_901_' in the outputs directory
# No result files found with prefix 'reference_batch2_902_' in the outputs directory
# No result files found with prefix 'reference_batch2_903_' in the outputs directory
# No result files found with prefix 'reference_batch2_904_' in the outputs directory
# No result files found with prefix 'reference_batch2_905_' in the outputs directory
# No result files found with prefix 'reference_batch2_906_' in the outputs directory
# No result files found with prefix 'reference_batch2_907_' in the outputs directory
# No result files found with prefix 'reference_batch2_908_' in the outputs directory
# No result files found with prefix 'reference_batch2_909_' in the outputs directory
# No result files found with prefix 'reference_batch2_910_' in the outputs directory
# No result files found with prefix 'reference_batch2_911_' in the outputs directory
# No result files found with prefix 'reference_batch2_912_' in the outputs directory
# No result files found with prefix 'reference_batch2_913_' in the outputs directory
# No result files found with prefix 'reference_batch2_914_' in the outputs directory
# No result files found with prefix 'reference_batch2_915_' in the outputs directory
# No result files found with prefix 'reference_batch2_916_' in the outputs directory
# No result files found with prefix 'reference_batch2_917_' in the outputs directory
# No result files found with prefix 'reference_batch2_918_' in the outputs directory
# No result files found with prefix 'reference_batch2_919_' in the outputs directory
# No result files found with prefix 'reference_batch2_920_' in the outputs directory
# No result files found with prefix 'reference_batch2_921_' in the outputs directory
# No result files found with prefix 'reference_batch2_922_' in the outputs directory
# No result files found with prefix 'reference_batch2_923_' in the outputs directory
# No result files found with prefix 'reference_batch2_924_' in the outputs directory
# No result files found with prefix 'reference_batch2_925_' in the outputs directory
# No result files found with prefix 'reference_batch2_926_' in the outputs directory
# No result files found with prefix 'reference_batch2_927_' in the outputs directory
# No result files found with prefix 'reference_batch2_928_' in the outputs directory
# No result files found with prefix 'reference_batch2_929_' in the outputs directory
# No result files found with prefix 'reference_batch2_930_' in the outputs directory
# No result files found with prefix 'reference_batch2_931_' in the outputs directory
# No result files found with prefix 'reference_batch2_932_' in the outputs directory
# No result files found with prefix 'reference_batch2_933_' in the outputs directory
# No result files found with prefix 'reference_batch2_934_' in the outputs directory
# No result files found with prefix 'reference_batch2_935_' in the outputs directory
# No result files found with prefix 'reference_batch2_936_' in the outputs directory
# No result files found with prefix 'reference_batch2_937_' in the outputs directory
# No result files found with prefix 'reference_batch2_938_' in the outputs directory
# No result files found with prefix 'reference_batch2_939_' in the outputs directory
# No result files found with prefix 'reference_batch2_940_' in the outputs directory
# No result files found with prefix 'reference_batch2_941_' in the outputs directory
# No result files found with prefix 'reference_batch2_942_' in the outputs directory
# No result files found with prefix 'reference_batch2_943_' in the outputs directory
# No result files found with prefix 'reference_batch2_944_' in the outputs directory
# No result files found with prefix 'reference_batch2_945_' in the outputs directory
# No result files found with prefix 'reference_batch2_946_' in the outputs directory
# No result files found with prefix 'reference_batch2_947_' in the outputs directory
# No result files found with prefix 'reference_batch2_948_' in the outputs directory
# No result files found with prefix 'reference_batch2_949_' in the outputs directory
# Processing index 950
# No result files found with prefix 'reference_batch2_950_' in the outputs directory
# No result files found with prefix 'reference_batch2_951_' in the outputs directory
# No result files found with prefix 'reference_batch2_952_' in the outputs directory
# No result files found with prefix 'reference_batch2_953_' in the outputs directory
# No result files found with prefix 'reference_batch2_954_' in the outputs directory
# No result files found with prefix 'reference_batch2_955_' in the outputs directory
# No result files found with prefix 'reference_batch2_956_' in the outputs directory
# No result files found with prefix 'reference_batch2_957_' in the outputs directory
# No result files found with prefix 'reference_batch2_958_' in the outputs directory
# No result files found with prefix 'reference_batch2_959_' in the outputs directory
# No result files found with prefix 'reference_batch2_960_' in the outputs directory
# No result files found with prefix 'reference_batch2_961_' in the outputs directory
# No result files found with prefix 'reference_batch2_962_' in the outputs directory
# No result files found with prefix 'reference_batch2_963_' in the outputs directory
# No result files found with prefix 'reference_batch2_964_' in the outputs directory
# No result files found with prefix 'reference_batch2_965_' in the outputs directory
# No result files found with prefix 'reference_batch2_966_' in the outputs directory
# No result files found with prefix 'reference_batch2_967_' in the outputs directory
# No result files found with prefix 'reference_batch2_968_' in the outputs directory
# No result files found with prefix 'reference_batch2_969_' in the outputs directory
# No result files found with prefix 'reference_batch2_970_' in the outputs directory
# No result files found with prefix 'reference_batch2_971_' in the outputs directory
# No result files found with prefix 'reference_batch2_972_' in the outputs directory
# No result files found with prefix 'reference_batch2_973_' in the outputs directory
# No result files found with prefix 'reference_batch2_974_' in the outputs directory
# No result files found with prefix 'reference_batch2_975_' in the outputs directory
# No result files found with prefix 'reference_batch2_976_' in the outputs directory
# No result files found with prefix 'reference_batch2_977_' in the outputs directory
# No result files found with prefix 'reference_batch2_978_' in the outputs directory
# No result files found with prefix 'reference_batch2_979_' in the outputs directory
# No result files found with prefix 'reference_batch2_980_' in the outputs directory
# No result files found with prefix 'reference_batch2_981_' in the outputs directory
# No result files found with prefix 'reference_batch2_982_' in the outputs directory
# No result files found with prefix 'reference_batch2_983_' in the outputs directory
# No result files found with prefix 'reference_batch2_984_' in the outputs directory
# No result files found with prefix 'reference_batch2_985_' in the outputs directory
# No result files found with prefix 'reference_batch2_986_' in the outputs directory
# No result files found with prefix 'reference_batch2_987_' in the outputs directory
# No result files found with prefix 'reference_batch2_988_' in the outputs directory
# No result files found with prefix 'reference_batch2_989_' in the outputs directory
# No result files found with prefix 'reference_batch2_990_' in the outputs directory
# No result files found with prefix 'reference_batch2_991_' in the outputs directory
# No result files found with prefix 'reference_batch2_992_' in the outputs directory
# No result files found with prefix 'reference_batch2_993_' in the outputs directory
# No result files found with prefix 'reference_batch2_994_' in the outputs directory
# No result files found with prefix 'reference_batch2_995_' in the outputs directory
# No result files found with prefix 'reference_batch2_996_' in the outputs directory
# No result files found with prefix 'reference_batch2_997_' in the outputs directory
# No result files found with prefix 'reference_batch2_998_' in the outputs directory
# No result files found with prefix 'reference_batch2_999_' in the outputs directory

# %%
import pandas as pd

# Read the original file
with open("outputs/response_test.txt", "r") as f:
    lines = f.readlines()

# Split each line and extract ID and label
full_data = [line.strip().split(", ")[1:] for line in lines]  # skip the first field (index)

# Create DataFrame
df = pd.DataFrame(full_data, columns=["ID", "label"])
df["label"] = df["label"].replace({
    "Unverifiable": "unver",
    "Contradiction": "contra",
    "Entailment": "entail"
})

# Drop exact duplicate rows (same ID and label)
df = df.drop_duplicates()

df.to_csv("outputs/kaggle_results/response_clean.csv", index=False)

# %%
df

# %%
results_df = dataset_loader["subtask1_train_batch2"][:100].copy()
results_df["true_label"] = results_df["label"]
results_df["predicted_label"]=  df.label[-100:].values
results_df

# %%
from sklearn.metrics import f1_score, classification_report


# Calculate evaluation metrics
true_labels = results_df['true_label'].tolist()
predicted_labels = results_df['predicted_label'].tolist()

# Calculate weighted F1 score (main evaluation metric)
weighted_f1 = f1_score(true_labels, predicted_labels, average='weighted')

print(f"\n=== EVALUATION RESULTS ===")
print(f"Total samples processed: {len(results_df)}")
print(f"Weighted F1 Score: {weighted_f1:.4f}")

# Calculate accuracy
accuracy = (results_df['true_label'] == results_df['predicted_label']).mean()
print(f"Accuracy: {accuracy:.4f}")

# Print detailed classification report
print(f"\n=== DETAILED CLASSIFICATION REPORT ===")
print(classification_report(true_labels, predicted_labels))

# Show results by batch
print(f"\n=== RESULTS BY BATCH ===")
for batch in results_df['batch'].unique():
    batch_results = results_df[results_df['batch'] == batch]
    batch_accuracy = (batch_results['true_label'] == batch_results['predicted_label']).mean()
    batch_f1 = f1_score(batch_results['true_label'], batch_results['predicted_label'], average='weighted')
    print(f"{batch}: Accuracy={batch_accuracy:.4f}, Weighted F1={batch_f1:.4f}")

# Calculate F1 scores for batch2 and batch3 separately
print(f"\n=== INDIVIDUAL BATCH F1 SCORES ===")
if 'batch2' in results_df['batch'].values:
    batch2_results = results_df[results_df['batch'] == 'batch2']
    batch2_f1 = f1_score(batch2_results['true_label'], batch2_results['predicted_label'], average='weighted')
    print(f"Batch2 Weighted F1 Score: {batch2_f1:.4f}")

if 'batch3' in results_df['batch'].values:
    batch3_results = results_df[results_df['batch'] == 'batch3']
    batch3_f1 = f1_score(batch3_results['true_label'], batch3_results['predicted_label'], average='weighted')
    print(f"Batch3 Weighted F1 Score: {batch3_f1:.4f}")

# Display first few results
print(f"\n=== SAMPLE RESULTS ===")
print(results_df.head(10))

# %%
set(df.index.unique())
