# %% [markdown]
# # Test with Gemini

# %%
import networkx as nx
from cheatsheet import CHEATSHEETS

def create_cheatsheet_knowledge_graph() -> nx.Graph:
    """
    Creates a NetworkX graph from the cheatsheet relationships.
    Returns:
        nx.Graph: Graph containing entity types as nodes and their relationships
    """
    G = nx.Graph()
    
    # Parse the cheatsheet relationships
    relationships = CHEATSHEETS["cheat_sheet_kg"].strip().split('\n')
    for relationship in relationships:
        if not relationship.strip():
            continue
            
        # Split on "-" and clean up whitespace
        nodes = [node.strip() for node in relationship.strip(';').split('-')]
        if len(nodes) == 2:
            source, target = nodes
            # Add nodes and edge
            G.add_node(source)
            G.add_node(target)
            G.add_edge(
                source, 
                target,
                description=f"Relationship between {source} and {target}",
                weight=1.0
            )
    
    return G
nx_graph = create_cheatsheet_knowledge_graph()

# %%
node_name = "Crop Type"

location_node = nx_graph.nodes[node_name]
neighbors = list(nx_graph.neighbors(node_name))
neighbor_edges = list(nx_graph.edges(node_name, data=True))
for edge in neighbor_edges:
    print(f"Edge: {edge[0]} -> {edge[1]}, Description: {edge[2].get('description', 'No description')}")
# Out:
# Edge: Crop Type -> Crop Yield, Description: Relationship between Crop Type and Crop Yield
# Edge: Crop Type -> Climate Drivers, Description: Relationship between Crop Type and Climate Drivers

# %%
nx_graph.get_edge_data("Crop Yield", "Climate Drivers")
# Out:
# {'description': 'Relationship between Crop Yield and Climate Drivers',
#  'weight': 1.0}

# %%
content = """
3.1.1 Impact of fixed rise in temperature, CO₂ and change in rain fall

Monsoon crop
Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a). Grain yield decreased with each degree rise in atmospheric temperature. However, the rate of decrease varied with location. The mean baseline yield of rainfed maize crop is about 2 Mg ha⁻¹ in UIGP, where the projected yield loss is up to 7, 11, 15, 22, and 33% relative to baseline yields with 1, 2, 3, 4, 5°C degrees rise in atmospheric temperatures. However, a 20% increase in rainfall is projected to offset the yield loss due to 1°C rise in temperature. Similarly, a 30% increase in rainfall is predicted to offset the adverse impact of 2°C rise in temperature. In MIGP region, yield reduction of about 8–35% with 1–5°C rise in atmospheric temperature is projected. In this region, increase in rainfall is likely to offset the temperature rise up to 0.75°C and any increase beyond this temperature will adversely impact the yields, in spite of increase in rainfall. The SP region is also projected to experience adverse impact with -10, -15, -23, -27 and -35% reductions from the baseline yield levels at each 1°C rise in temperature. A 10% increase in rainfall will offset the reduction in yield due to 1°C rise in temperature in this region.

Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV. The benefits are projected to be high in mild water stress conditions, but they are likely to reduce in severe water stress situations (Table 3). The yield gains due to increase in atmospheric CO₂ concentration are projected to be more in SP regions (low rainfall area) followed by UIGP and MIGP regions.

Winter crop
Maize crop during winter is provided with assured irrigation and thus yields about 1.5 times more than that of monsoon crop. Winter maize grain yield reduced with increase in temperatures in SP and MIGP, but in UIGP rise in temperatures up to 2.7°C is likely to improve the maize yields. However, further increase in temperature is projected to reduce grain yields and the reductions are likely to be more than those at MIGP and SP (Fig. 3a). In UIGP, this beneficial effect with rise in temperature is projected to be more up to 2°C rise (13% increase over current yields). In this region, yield will improve with 2°C in spite of reduction in rainfall. In the event of further increase in temperature to about 2.7°C, the reduction in yields can be offset only if rainfall is increased or more irrigation is provided. With temperature rise, the crop experiences conditions closer to optimal temperature during grain development, benefiting grain number. Relatively low temperature during grain filling period required more days to satisfy thermal time requirement. However, in both MIGP and SP, where the average maximum temperatures during winter crop season are relatively higher (Table 2), any increase in temperature can cause reduction in yield.

Table 3 Influence of atmospheric carbon dioxide concentration on maize yields in rainfall deficit conditions during monsoon season

In UIGP, rise in temperatures beyond 2.7°C caused reduction in yield mainly due to reduced number of grains. This limited the gains in spite of increase in GFD and individual grain weight. Further increase in temperature resulted in yield reduction from current yields. In UIGP, GFD was found to increase with rise in temperature because of current lower temperature during winter. While the rise in temperature prolonged GFD significantly at UIGP than at MIGP, it actually reduced at SP. In all locations, flowering hastened due to increase in temperature.
3.1.2 Impact of climate change scenarios on maize yield

The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model. This approach was followed because of reported spatio-temporal variations in climate change scenarios (IPCC 2007).

Monsoon crop
The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a). This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number. This implies that the maize crop may benefit from additional availability of water in spite of increase in temperature and related reduction in crop duration by 3–4 days. On the other hand, in MIGP, maize is likely to suffer yield loss in future scenarios. The loss from current yields is projected to be ~5%, ~13%, ~17% in 2020, 2050 and 2080, respectively. In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later. Projected rise in daytime temperature during monsoon is higher in SP and MIGP as compared to UIGP region, even though minimum temperatures are projected to rise almost similarly in these locations. Apart from this, rainfall is projected to increase in UIGP while it is likely to change in MIGP. Thus, the spatio-temporal variation in existing climatic conditions and projected changes in temperature and rainfall would bring about differential impacts on monsoon maize crop in India.

Winter crop
As far as maize crop grown in winter is concerned, yield gains are projected to be ~5% over current yield in 2020 scenario at UIGP and this benefit is likely to remain till 2050 (Fig. 4b). However, in 2080 scenario, yields are projected to be reduced by 25% from current yields. Winter maize in MIGP, currently a high yielding zone, is projected to suffer in post-2020 scenario. The reduction in yield is likely to be to the tune of ~50% by 2050 and about 60% by 2080. In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080. In these areas, winter maize is well irrigated and thus variation in winter rainfall, which otherwise is low, is less influential. The projected rise in temperature during winter crop season is more in UIGP in 2020 and 2050 than in MIGP and SP, particularly during later part of crop growth.
"""

# %%
import asyncio
import os
from dotenv import load_dotenv
from operationCheatSheet import chunking_by_token_size, extract_entities
from utils import compute_mdhash_id
from geminillm import gemini_complete_if_cache
from openaillm import openai_embed, openai_complete
from faiss_impl import FaissVectorDBStorage
from networkx_impl import NetworkXStorage
from json_kv_iml import JsonKVStorage
from shared_storage import initialize_share_data
from cheatsheet import CHEATSHEETS
from grobidmonkey import reader

# LLM_MODEL_NAME = "gpt-3.5-turbo"
LLM_MODEL_NAME = "gemini-2.5-flash-preview-04-17"

load_dotenv()

async def process_text_to_knowledge_graph(text_content,
                                          cheatsheet_knowledge_graph_inst,
                                          file_path="unknown_source"):
    # Step 1: Create chunks from your text content
    raw_chunks = chunking_by_token_size(
        content=text_content,
        split_by_character=None,  # Optional: specify a character to split by (e.g., "\n\n")
        split_by_character_only=False,
        overlap_token_size=128,
        max_token_size=1024,
        tiktoken_model=LLM_MODEL_NAME
    )
    
    # Step 2: Format chunks as required by extract_entities
    doc_id = compute_mdhash_id(text_content, prefix="doc-")
    chunks = {
        compute_mdhash_id(chunk["content"], prefix="chunk-"): {
            **chunk,
            "full_doc_id": doc_id,
            "file_path": file_path
        }
        for chunk in raw_chunks
    }
    
    # Step 3: Initialize your storage instances
    faiss_global_config = {
        "working_dir": "/tmp",
        "embedding_batch_num": 64,  # or another integer suitable for your setup
        "vector_db_storage_cls_kwargs": {
            "cosine_better_than_threshold": 0.2  # or another float threshold you want
        },
        "base_url": "https://api.openai.com/v1",
    }
    kv_global_config = {
        "working_dir": "/tmp",
        "llm_model_name": LLM_MODEL_NAME,
        "embedding_batch_num": 64,  # or another integer suitable for your setup
        "vector_db_storage_cls_kwargs": {
            "cosine_better_than_threshold": 0.2  # or another float threshold you want
        },
        "base_url": "https://api.openai.com/v1",
    }
    knowledge_graph = NetworkXStorage(namespace="nx_kg", global_config=faiss_global_config, embedding_func=openai_embed)  # Graph storage implementation
    entity_vector_db = FaissVectorDBStorage(namespace="faiss_entity", global_config=faiss_global_config, embedding_func=openai_embed)  # Vector storage for entities
    relationship_vector_db = FaissVectorDBStorage(namespace="faiss_relationship", global_config=faiss_global_config, embedding_func=openai_embed)  # Vector storage for relationships
    llm_cache = JsonKVStorage(namespace="llm_cache", global_config=kv_global_config, embedding_func=openai_embed)
    
    initialize_share_data()

    await knowledge_graph.initialize()
    await entity_vector_db.initialize()
    await relationship_vector_db.initialize()
    await llm_cache.initialize()  # if your cache supports/needs it

    # Step 4: Use the OpenAI LLM function from openai.py
    # Create a wrapper that matches the expected signature for extract_entities
    async def llm_wrapper(prompt, history_messages=None, max_tokens=None, **kwargs):
        if history_messages is None:
            history_messages = []
    

        # Use Google GenAI
        return await gemini_complete_if_cache(
            model=LLM_MODEL_NAME,
            prompt=prompt,
            history_messages=history_messages,
            hashing_kv=llm_cache,
            temperature=0.2,
            max_tokens=max_tokens or 1024,
        )

        
    
    # Step 5: Configure the extraction process
    global_config = {
        "llm_model_func": llm_wrapper,  # Use our wrapper function
        "llm_model_name": LLM_MODEL_NAME,  # Required for some OpenAI functions
        "entity_extract_max_gleaning": 2,
        "force_llm_summary_on_merge": False,
        "llm_model_max_token_size": 1024,
        "summary_to_max_tokens": 256,
        "tiktoken_model_name": LLM_MODEL_NAME,
        "addon_params": {
            "language": "English",
            "entity_types": ["Crop Type",
                             "Crop Yield",
                             "Climate Drivers",
                             "Experimental Design",
                             "Location",
                             "Time"]
        },
    }
    
    # Step 6: Optional status tracking
    pipeline_status = {
        "latest_message": "",
        "history_messages": []
    }
    pipeline_status_lock = asyncio.Lock()
    
    # Step 7: Run the extraction
    await extract_entities(
        chunks=chunks,
        knowledge_graph_inst=knowledge_graph,
        entity_vdb=entity_vector_db,
        relationships_vdb=relationship_vector_db,
        global_config=global_config,
        pipeline_status=pipeline_status,
        pipeline_status_lock=pipeline_status_lock,
        llm_response_cache=llm_cache,
        cheatsheet_knowledge_graph_inst=cheatsheet_knowledge_graph_inst,
        write_result_to_txt=True
    )
    
    return knowledge_graph

# Example usage in a Jupyter notebook
async def main():
    # monkeyReader = reader.MonkeyReader('monkey') # or 'lxml' or 'x2d'

    # read paper content
    # essay = monkeyReader.readEssay('./xmldata/Byjesh.pdf.tei.xml')
    # text = "\n".join(essay["Impact of fixed rise in temperature, CO 2 and change in rain fall"])
    text = content
    knowledge_graph = await process_text_to_knowledge_graph(text, nx_graph, "example.txt")
    # Now you can query the knowledge graph for entities and relationships
    
    return knowledge_graph

# In a Jupyter notebook, you can run this with:
knowledge_graph = await main()
# Out:
# No existing Faiss index file found. Starting fresh.
# No existing Faiss index file found. Starting fresh.
# INFO: Process 22792 Shared-Data created for Single Process
# INFO: Process 22792 initialized updated flags for namespace: [nx_kg]
# INFO: Process 22792 initialized updated flags for namespace: [faiss_entity]
# INFO: Process 22792 initialized updated flags for namespace: [faiss_relationship]
# INFO: Process 22792 initialized updated flags for namespace: [llm_cache]
# INFO: Process 22792 ready to initialize storage namespace: [llm_cache]
# /home/com3dian/Github/llmMetaData/operationCheatSheet.py:728: RuntimeWarning: coroutine 'extract_entities.<locals>.nightly_kg_to_text' was never awaited
#   hint_prompt = fill_nightly_prompt.format(
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Final result:
# ("entity"<|>"Maize Crop"<|>"Maize Crop"<|>"Crop Type"<|>"Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a)."<|>"maize"<|><source_id><|><file_path>)##
# ("entity"<|>"Monsoon Maize Yield"<|>"Monsoon Maize Yield"<|>"Crop Yield"<|>"Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a)."<|>"maize yields in monsoon season"<|><source_id><|><file_path>)##
# ("entity"<|>"Winter Maize Yield"<|>"Winter Maize Yield"<|>"Crop Yield"<|>"Maize crop during winter is provided with assured irrigation and thus yields about 1.5 times more than that of monsoon crop."<|>"Winter maize grain yield"<|><source_id><|><file_path>)##
# ("entity"<|>"Baseline Yield"<|>"Baseline Yield"<|>"Crop Yield"<|>"The mean baseline yield of rainfed maize crop is about 2 Mg ha⁻¹ in UIGP, where the projected yield loss is up to 7, 11, 15, 22, and 33% relative to baseline yields with 1, 2, 3, 4, 5°C degrees rise in atmospheric temperatures."<|>"baseline yield"<|><source_id><|><file_path>)##
# ("entity"<|>"Temperature"<|>"Temperature"<|>"Climate Drivers"<|>"Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a)."<|>"rise in atmospheric temperatures"<|><source_id><|><file_path>)##
# ("entity"<|>"CO₂ Concentration"<|>"CO₂ Concentration"<|>"Climate Drivers"<|>"Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV."<|>"carbon dioxide"<|><source_id><|><file_path>)##
# ("entity"<|>"Rainfall"<|>"Rainfall"<|>"Climate Drivers"<|>"However, a 20% increase in rainfall is projected to offset the yield loss due to 1°C rise in temperature."<|>"rainfall"<|><source_id><|><file_path>)##
# ("entity"<|>"Water Availability"<|>"Water Availability"<|>"Climate Drivers"<|>"This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number."<|>"additional availability of water"<|><source_id><|><file_path>)##
# ("entity"<|>"Water Stress Conditions"<|>"Water Stress Conditions"<|>"Climate Drivers"<|>"The benefits are projected to be high in mild water stress conditions, but they are likely to reduce in severe water stress situations (Table 3)."<|>"water stress conditions"<|><source_id><|><file_path>)##
# ("entity"<|>"UIGP Region"<|>"UIGP Region"<|>"Location"<|>"The mean baseline yield of rainfed maize crop is about 2 Mg ha⁻¹ in UIGP, where the projected yield loss is up to 7, 11, 15, 22, and 33% relative to baseline yields with 1, 2, 3, 4, 5°C degrees rise in atmospheric temperatures."<|>"UIGP"<|><source_id><|><file_path>)##
# ("entity"<|>"MIGP Region"<|>"MIGP Region"<|>"Location"<|>"In MIGP region, yield reduction of about 8–35% with 1–5°C rise in atmospheric temperature is projected."<|>"MIGP region"<|><source_id><|><file_path>)##
# ("entity"<|>"SP Region"<|>"SP Region"<|>"Location"<|>"The SP region is also projected to experience adverse impact with -10, -15, -23, -27 and -35% reductions from the baseline yield levels at each 1°C rise in temperature."<|>"SP region"<|><source_id><|><file_path>)##
# ("entity"<|>"Monsoon Season"<|>"Monsoon Season"<|>"Time"<|>"Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a)."<|>"monsoon season"<|><source_id><|><file_path>)##
# ("entity"<|>"Winter Season"<|>"Winter Season"<|>"Time"<|>"Maize crop during winter is provided with assured irrigation and thus yields about 1.5 times more than that of monsoon crop."<|>"winter"<|><source_id><|><file_path>)##
# ("entity"<|>"Grain Development"<|>"Grain Development"<|>"Time"<|>"With temperature rise, the crop experiences conditions closer to optimal temperature during grain development, benefiting grain number."<|>"grain development"<|><source_id><|><file_path>)##
# ("entity"<|>"Grain Filling Period"<|>"Grain Filling Period"<|>"Time"<|>"Relatively low temperature during grain filling period required more days to satisfy thermal time requirement."<|>"grain filling period"<|><source_id><|><file_path>)##
# ("entity"<|>"Flowering"<|>"Flowering"<|>"Time"<|>"In all locations, flowering hastened due to increase in temperature."<|>"flowering"<|><source_id><|><file_path>)##
# ("entity"<|>"Simulation Analysis"<|>"Simulation Analysis"<|>"Experimental Design"<|>"Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a)."<|>"simulation analysis"<|><source_id><|><file_path>)##
# ("entity"<|>"Climate Change Scenarios"<|>"Climate Change Scenarios"<|>"Experimental Design"<|>"The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model."<|>"climate change scenarios"<|><source_id><|><file_path>)##
# ("entity"<|>"InfoCrop-MAIZE Model"<|>"InfoCrop-MAIZE Model"<|>"Experimental Design"<|>"The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model."<|>"InfoCrop-MAIZE model"<|><source_id><|><file_path>)##
# ("entity"<|>"HadCM3 Model"<|>"HadCM3 Model"<|>"Experimental Design"<|>"The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model."<|>"HadCM3 model"<|><source_id><|><file_path>)##
# ("entity"<|>"Bern CC Model"<|>"Bern CC Model"<|>"Experimental Design"<|>"The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model."<|>"Bern CC model"<|><source_id><|><file_path>)##
# ("entity"<|>"Grain Number"<|>"Grain Number"<|>"Crop Yield"<|>"With temperature rise, the crop experiences conditions closer to optimal temperature during grain development, benefiting grain number."<|>"grain number"<|><source_id><|><file_path>)##
# ("entity"<|>"Dry Matter Production"<|>"Dry Matter Production"<|>"Crop Yield"<|>"This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number."<|>"dry matter production"<|><source_id><|><file_path>)##
# ("entity"<|>"Individual Grain Weight"<|>"Individual Grain Weight"<|>"Crop Yield"<|>"This limited the gains in spite of increase in GFD and individual grain weight."<|>"individual grain weight"<|><source_id><|><file_path>)##
# ("entity"<|>"GFD"<|>"GFD"<|>"Experimental Design"<|>"In UIGP, GFD was found to increase with rise in temperature because of current lower temperature during winter."<|>"GFD"<|><source_id><|><file_path>)##
# ("entity"<|>"Thermal Time Requirement"<|>"Thermal Time Requirement"<|>"Experimental Design"<|>"Relatively low temperature during grain filling period required more days to satisfy thermal time requirement."<|>"thermal time requirement"<|><source_id><|><file_path>)##
# ("entity"<|>"Reduced Grain Number"<|>"Reduced Grain Number"<|>"Crop Yield"<|>"In UIGP, rise in temperatures beyond 2.7°C caused reduction in yield mainly due to reduced number of grains."<|>"reduced number of grains"<|><source_id><|><file_path>)##
# ("relationship"<|>"Monsoon Maize Yield"<|>"Temperature"<|>"Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a)."<|>"yield impact, climate stress"<|>9)##
# ("relationship"<|>"Monsoon Maize Yield"<|>"UIGP Region"<|>"The mean baseline yield of rainfed maize crop is about 2 Mg ha⁻¹ in UIGP, where the projected yield loss is up to 7, 11, 15, 22, and 33% relative to baseline yields with 1, 2, 3, 4, 5°C degrees rise in atmospheric temperatures."<|>"regional yield, baseline comparison"<|>8)##
# ("relationship"<|>"Monsoon Maize Yield"<|>"MIGP Region"<|>"In MIGP region, yield reduction of about 8–35% with 1–5°C rise in atmospheric temperature is projected."<|>"regional yield, climate impact"<|>8)##
# ("relationship"<|>"Monsoon Maize Yield"<|>"SP Region"<|>"The SP region is also projected to experience adverse impact with -10, -15, -23, -27 and -35% reductions from the baseline yield levels at each 1°C rise in temperature."<|>"regional yield, climate impact"<|>8)##
# ("relationship"<|>"Monsoon Maize Yield"<|>"Baseline Yield"<|>"The mean baseline yield of rainfed maize crop is about 2 Mg ha⁻¹ in UIGP, where the projected yield loss is up to 7, 11, 15, 22, and 33% relative to baseline yields with 1, 2, 3, 4, 5°C degrees rise in atmospheric temperatures."<|>"yield comparison, baseline"<|>8)##
# ("relationship"<|>"Rainfall"<|>"Monsoon Maize Yield"<|>"However, a 20% increase in rainfall is projected to offset the yield loss due to 1°C rise in temperature."<|>"climate interaction, yield mitigation"<|>9)##
# ("relationship"<|>"CO₂ Concentration"<|>"Maize Crop"<|>"Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV."<|>"climate impact, crop benefit"<|>9)##
# ("relationship"<|>"CO₂ Concentration"<|>"Water Stress Conditions"<|>"The benefits are projected to be high in mild water stress conditions, but they are likely to reduce in severe water stress situations (Table 3)."<|>"climate interaction, yield modification"<|>8)##
# ("relationship"<|>"CO₂ Concentration"<|>"SP Region"<|>"The yield gains due to increase in atmospheric CO₂ concentration are projected to be more in SP regions (low rainfall area) followed by UIGP and MIGP regions."<|>"regional variation, climate benefit"<|>7)##
# ("relationship"<|>"CO₂ Concentration"<|>"UIGP Region"<|>"The yield gains due to increase in atmospheric CO₂ concentration are projected to be more in SP regions (low rainfall area) followed by UIGP and MIGP regions."<|>"regional variation, climate benefit"<|>7)##
# ("relationship"<|>"CO₂ Concentration"<|>"MIGP Region"<|>"The yield gains due to increase in atmospheric CO₂ concentration are projected to be more in SP regions (low rainfall area) followed by UIGP and MIGP regions."<|>"regional variation, climate benefit"<|>7)##
# ("relationship"<|>"Winter Season"<|>"Winter Maize Yield"<|>"Maize crop during winter is provided with assured irrigation and thus yields about 1.5 times more than that of monsoon crop."<|>"seasonal yield, management effect"<|>8)##
# ("relationship"<|>"Winter Maize Yield"<|>"Monsoon Maize Yield"<|>"Maize crop during winter is provided with assured irrigation and thus yields about 1.5 times more than that of monsoon crop."<|>"seasonal yield comparison"<|>7)##
# ("relationship"<|>"Winter Maize Yield"<|>"Temperature"<|>"Winter maize grain yield reduced with increase in temperatures in SP and MIGP, but in UIGP rise in temperatures up to 2.7°C is likely to improve the maize yields."<|>"yield impact, climate stress"<|>9)##
# ("relationship"<|>"Winter Maize Yield"<|>"UIGP Region"<|>"Winter maize grain yield reduced with increase in temperatures in SP and MIGP, but in UIGP rise in temperatures up to 2.7°C is likely to improve the maize yields."<|>"regional yield response, climate benefit"<|>8)##
# ("relationship"<|>"Winter Maize Yield"<|>"MIGP Region"<|>"Winter maize grain yield reduced with increase in temperatures in SP and MIGP, but in UIGP rise in temperatures up to 2.7°C is likely to improve the maize yields."<|>"regional yield response, climate stress"<|>8)##
# ("relationship"<|>"Winter Maize Yield"<|>"SP Region"<|>"Winter maize grain yield reduced with increase in temperatures in SP and MIGP, but in UIGP rise in temperatures up to 2.7°C is likely to improve the maize yields."<|>"regional yield response, climate stress"<|>8)##
# ("relationship"<|>"Temperature"<|>"Grain Development"<|>"With temperature rise, the crop experiences conditions closer to optimal temperature during grain development, benefiting grain number."<|>"climate impact, developmental timing"<|>9)##
# ("relationship"<|>"Temperature"<|>"Grain Number"<|>"With temperature rise, the crop experiences conditions closer to optimal temperature during grain development, benefiting grain number."<|>"climate impact, yield component"<|>9)##
# ("relationship"<|>"Temperature"<|>"Grain Filling Period"<|>"Relatively low temperature during grain filling period required more days to satisfy thermal time requirement."<|>"climate impact, developmental timing"<|>8)##
# ("relationship"<|>"Temperature"<|>"Flowering"<|>"In all locations, flowering hastened due to increase in temperature."<|>"climate impact, developmental timing"<|>9)##
# ("relationship"<|>"Temperature"<|>"GFD"<|>"In UIGP, GFD was found to increase with rise in temperature because of current lower temperature during winter."<|>"climate impact, yield component proxy"<|>8)##
# ("relationship"<|>"GFD"<|>"UIGP Region"<|>"In UIGP, GFD was found to increase with rise in temperature because of current lower temperature during winter."<|>"regional variation, yield component proxy"<|>7)##
# ("relationship"<|>"GFD"<|>"SP Region"<|>"While the rise in temperature prolonged GFD significantly at UIGP than at MIGP, it actually reduced at SP."<|>"regional variation, yield component proxy"<|>7)##
# ("relationship"<|>"Reduced Grain Number"<|>"Monsoon Maize Yield"<|>"In UIGP, rise in temperatures beyond 2.7°C caused reduction in yield mainly due to reduced number of grains."<|>"yield component impact"<|>9)##
# ("relationship"<|>"Climate Change Scenarios"<|>"InfoCrop-MAIZE Model"<|>"The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model."<|>"model coupling, experimental method"<|>10)##
# ("relationship"<|>"HadCM3 Model"<|>"Climate Change Scenarios"<|>"The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model."<|>"model output, scenario source"<|>9)##
# ("relationship"<|>"Bern CC Model"<|>"Climate Change Scenarios"<|>"The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model."<|>"model output, scenario source"<|>9)##
# ("relationship"<|>"Climate Change Scenarios"<|>"UIGP Region"<|>"The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a)."<|>"regional impact, scenario simulation"<|>8)##
# ("relationship"<|>"Climate Change Scenarios"<|>"Monsoon Maize Yield"<|>"The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a)."<|>"yield impact, scenario simulation"<|>9)##
# ("relationship"<|>"Rainfall"<|>"Dry Matter Production"<|>"This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number."<|>"climate impact, yield component"<|>9)##
# ("relationship"<|>"Rainfall"<|>"Grain Number"<|>"This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number."<|>"climate impact, yield component"<|>9)<|COMPLETE|>
# Final result:
# ("entity"<|>"Maize"<|>"crop_type"<|>"This implies that the maize crop may benefit from additional availability of water in spite of increase in temperature and related reduction in crop duration by 3–4 days."<|>"maize crop")##
# ("entity"<|>"Climate Change"<|>"climate_drivers"<|>"The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a)."<|>"climate change")##
# ("entity"<|>"UIGP Region"<|>"location"<|>"The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a)."<|>"UIGP region")##
# ("entity"<|>"2020 Scenario"<|>"experimental_design"<|>"The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a)."<|>"2020 scenario")##
# ("entity"<|>"2050 Scenario"<|>"experimental_design"<|>"The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a)."<|>"2050 scenario")##
# ("entity"<|>"2080 Scenario"<|>"experimental_design"<|>"The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a)."<|>"2080 scenario")##
# ("entity"<|>"Monsoon Maize Crop Productivity"<|>"crop_yield"<|>"The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a)."<|>"productivity of monsoon maize crop")##
# ("entity"<|>"Increase in Rainfall"<|>"climate_drivers"<|>"This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number."<|>"increase in rainfall")##
# ("entity"<|>"Dry Matter Production"<|>"crop_yield"<|>"This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number."<|>"improved dry matter production")##
# ("entity"<|>"Increase in Grain Number"<|>"crop_yield"<|>"This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number."<|>"increase in grain number")##
# ("entity"<|>"Additional Water Availability"<|>"climate_drivers"<|>"This implies that the maize crop may benefit from additional availability of water in spite of increase in temperature and related reduction in crop duration by 3–4 days."<|>"additional availability of water")##
# ("entity"<|>"Increase in Temperature"<|>"climate_drivers"<|>"This implies that the maize crop may benefit from additional availability of water in spite of increase in temperature and related reduction in crop duration by 3–4 days."<|>"increase in temperature")##
# ("entity"<|>"Reduction in Crop Duration"<|>"time"<|>"This implies that the maize crop may benefit from additional availability of water in spite of increase in temperature and related reduction in crop duration by 3–4 days."<|>"reduction in crop duration by 3–4 days")##
# ("entity"<|>"MIGP Region"<|>"location"<|>"On the other hand, in MIGP, maize is likely to suffer yield loss in future scenarios."<|>"MIGP")##
# ("entity"<|>"Maize Yield Loss in MIGP"<|>"crop_yield"<|>"On the other hand, in MIGP, maize is likely to suffer yield loss in future scenarios."<|>"yield loss")##
# ("entity"<|>"~5% Yield Loss in MIGP by 2020"<|>"crop_yield"<|>"The loss from current yields is projected to be ~5%, ~13%, ~17% in 2020, 2050 and 2080, respectively."<|>"loss from current yields is projected to be ~5%")##
# ("entity"<|>"~13% Yield Loss in MIGP by 2050"<|>"crop_yield"<|>"The loss from current yields is projected to be ~5%, ~13%, ~17% in 2020, 2050 and 2080, respectively."<|>"~13%")##
# ("entity"<|>"~17% Yield Loss in MIGP by 2080"<|>"crop_yield"<|>"The loss from current yields is projected to be ~5%, ~13%, ~17% in 2020, 2050 and 2080, respectively."<|>"~17%")##
# ("entity"<|>"SP Region"<|>"location"<|>"In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later."<|>"SP")##
# ("entity"<|>"21% Grain Yield Loss in SP by 2020"<|>"crop_yield"<|>"In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later."<|>"lose grain yield by 21%")##
# ("entity"<|>"35% Grain Yield Loss in SP by 2050"<|>"crop_yield"<|>"In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later."<|>"35% by 2050")##
# ("entity"<|>"Projected Rise in Daytime Temperature"<|>"climate_drivers"<|>"Projected rise in daytime temperature during monsoon is higher in SP and MIGP as compared to UIGP region, even though minimum temperatures are projected to rise almost similarly in these locations."<|>"Projected rise in daytime temperature")##
# ("entity"<|>"Projected Rise in Minimum Temperatures"<|>"climate_drivers"<|>"Projected rise in daytime temperature during monsoon is higher in SP and MIGP as compared to UIGP region, even though minimum temperatures are projected to rise almost similarly in these locations."<|>"minimum temperatures are projected to rise almost similarly")##
# ("entity"<|>"Spatio-Temporal Variation"<|>"experimental_design"<|>"Thus, the spatio-temporal variation in existing climatic conditions and projected changes in temperature and rainfall would bring about differential impacts on monsoon maize crop in India."<|>"spatio-temporal variation")##
# ("entity"<|>"Projected Changes in Temperature"<|>"climate_drivers"<|>"Thus, the spatio-temporal variation in existing climatic conditions and projected changes in temperature and rainfall would bring about differential impacts on monsoon maize crop in India."<|>"projected changes in temperature")##
# ("entity"<|>"Projected Changes in Rainfall"<|>"climate_drivers"<|>"Thus, the spatio-temporal variation in existing climatic conditions and projected changes in temperature and rainfall would bring about differential impacts on monsoon maize crop in India."<|>"projected changes in rainfall")##
# ("entity"<|>"Monsoon Maize Crop in India"<|>"crop_type"<|>"Thus, the spatio-temporal variation in existing climatic conditions and projected changes in temperature and rainfall would bring about differential impacts on monsoon maize crop in India."<|>"monsoon maize crop in India")##
# ("entity"<|>"Winter Maize Crop"<|>"crop_type"<|>"As far as maize crop grown in winter is concerned, yield gains are projected to be ~5% over current yield in 2020 scenario at UIGP and this benefit is likely to remain till 2050 (Fig. 4b)."<|>"maize crop grown in winter")##
# ("entity"<|>"~5% Yield Gains in UIGP by 2020"<|>"crop_yield"<|>"As far as maize crop grown in winter is concerned, yield gains are projected to be ~5% over current yield in 2020 scenario at UIGP and this benefit is likely to remain till 2050 (Fig. 4b)."<|>"yield gains are projected to be ~5% over current yield")##
# ("entity"<|>"Winter Maize Yield Reduction by 25% in UIGP by 2080"<|>"crop_yield"<|>"However, in 2080 scenario, yields are projected to be reduced by 25% from current yields."<|>"yields are projected to be reduced by 25% from current yields")##
# ("entity"<|>"Winter Maize in MIGP"<|>"crop_type"<|>"Winter maize in MIGP, currently a high yielding zone, is projected to suffer in post-2020 scenario."<|>"Winter maize in MIGP")##
# ("entity"<|>"Winter Maize Yield Reduction by ~50% in MIGP by 2050"<|>"crop_yield"<|>"The reduction in yield is likely to be to the tune of ~50% by 2050 and about 60% by 2080."<|>"reduction in yield is likely to be to the tune of ~50% by 2050")##
# ("entity"<|>"Winter Maize Yield Reduction by ~60% in MIGP by 2080"<|>"crop_yield"<|>"The reduction in yield is likely to be to the tune of ~50% by 2050 and about 60% by 2080."<|>"about 60% by 2080")##
# ("entity"<|>"Winter Maize in SP"<|>"crop_type"<|>"In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080."<|>"winter maize in SP region")##
# ("entity"<|>"Winter Maize Yield Decline by 13% in SP by 2020"<|>"crop_yield"<|>"In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080."<|>"yields are projected to decline by about 13% in 2020")##
# ("entity"<|>"Winter Maize Yield Decline by 17% in SP by 2050"<|>"crop_yield"<|>"In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080."<|>"17% in 2050")##
# ("entity"<|>"Winter Maize Yield Decline by 21% in SP by 2080"<|>"crop_yield"<|>"In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080."<|>"21% in 2080")##
# ("entity"<|>"Projected Rise in Temperature During Winter"<|>"climate_drivers"<|>"The projected rise in temperature during winter crop season is more in UIGP in 2020 and 2050 than in MIGP and SP, particularly during later part of crop growth."<|>"The projected rise in temperature during winter crop season")##
# ("relationship"<|>"Climate Change"<|>"Monsoon Maize Crop Productivity"<|>"The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a)."<|>"impact, yield"<|>8)##
# ("relationship"<|>"Climate Change"<|>"Maize Yield Loss in MIGP"<|>"On the other hand, in MIGP, maize is likely to suffer yield loss in future scenarios."<|>"impact, yield loss"<|>9)##
# ("relationship"<|>"Climate Change"<|>"21% Grain Yield Loss in SP by 2020"<|>"In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later."<|>"impact, yield loss"<|>9)##
# ("relationship"<|>"UIGP Region"<|>"Monsoon Maize Crop Productivity"<|>"The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a)."<|>"location, yield"<|>7)##
# ("relationship"<|>"MIGP Region"<|>"Maize Yield Loss in MIGP"<|>"On the other hand, in MIGP, maize is likely to suffer yield loss in future scenarios."<|>"location, yield loss"<|>7)##
# ("relationship"<|>"SP Region"<|>"21% Grain Yield Loss in SP by 2020"<|>"In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later."<|>"location, yield loss"<|>7)##
# ("relationship"<|>"2020 Scenario"<|>"Monsoon Maize Crop Productivity"<|>"The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a)."<|>"time, yield"<|>7)##
# ("relationship"<|>"2050 Scenario"<|>"Monsoon Maize Crop Productivity"<|>"The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a)."<|>"time, yield"<|>7)##
# ("relationship"<|>"2080 Scenario"<|>"Monsoon Maize Crop Productivity"<|>"The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a)."<|>"time, yield"<|>7)##
# ("relationship"<|>"Increase in Rainfall"<|>"Dry Matter Production"<|>"This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number."<|>"cause, yield component"<|>9)##
# ("relationship"<|>"Increase in Rainfall"<|>"Increase in Grain Number"<|>"This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number."<|>"cause, yield component"<|>9)##
# ("relationship"<|>"Additional Water Availability"<|>"Maize"<|>"This implies that the maize crop may benefit from additional availability of water in spite of increase in temperature and related reduction in crop duration by 3–4 days."<|>"benefit, climate factor"<|>8)##
# ("relationship"<|>"Increase in Temperature"<|>"Reduction in Crop Duration"<|>"This implies that the maize crop may benefit from additional availability of water in spite of increase in temperature and related reduction in crop duration by 3–4 days."<|>"cause, time"<|>8)##
# ("relationship"<|>"MIGP Region"<|>"~5% Yield Loss in MIGP by 2020"<|>"The loss from current yields is projected to be ~5%, ~13%, ~17% in 2020, 2050 and 2080, respectively."<|>"location, yield loss"<|>8)##
# ("relationship"<|>"MIGP Region"<|>"~13% Yield Loss in MIGP by 2050"<|>"The loss from current yields is projected to be ~5%, ~13%, ~17% in 2020, 2050 and 2080, respectively."<|>"location, yield loss"<|>8)##
# ("relationship"<|>"MIGP Region"<|>"~17% Yield Loss in MIGP by 2080"<|>"The loss from current yields is projected to be ~5%, ~13%, ~17% in 2020, 2050 and 2080, respectively."<|>"location, yield loss"<|>8)##
# ("relationship"<|>"2020 Scenario"<|>"~5% Yield Loss in MIGP by 2020"<|>"The loss from current yields is projected to be ~5%, ~13%, ~17% in 2020, 2050 and 2080, respectively."<|>"time, yield loss"<|>8)##
# ("relationship"<|>"2050 Scenario"<|>"~13% Yield Loss in MIGP by 2050"<|>"The loss from current yields is projected to be ~5%, ~13%, ~17% in 2020, 2050 and 2080, respectively."<|>"time, yield loss"<|>8)##
# ("relationship"<|>"2080 Scenario"<|>"~17% Yield Loss in MIGP by 2080"<|>"The loss from current yields is projected to be ~5%, ~13%, ~17% in 2020, 2050 and 2080, respectively."<|>"time, yield loss"<|>8)##
# ("relationship"<|>"SP Region"<|>"21% Grain Yield Loss in SP by 2020"<|>"In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later."<|>"location, yield loss"<|>8)##
# ("relationship"<|>"SP Region"<|>"35% Grain Yield Loss in SP by 2050"<|>"In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later."<|>"location, yield loss"<|>8)##
# ("relationship"<|>"2020 Scenario"<|>"21% Grain Yield Loss in SP by 2020"<|>"In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later."<|>"time, yield loss"<|>8)##
# ("relationship"<|>"2050 Scenario"<|>"35% Grain Yield Loss in SP by 2050"<|>"In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 250 and later."<|>"time, yield loss"<|>8)##
# ("relationship"<|>"Projected Rise in Daytime Temperature"<|>"SP Region"<|>"Projected rise in daytime temperature during monsoon is higher in SP and MIGP as compared to UIGP region, even though minimum temperatures are projected to rise almost similarly in these locations."<|>"climate factor, location"<|>7)##
# ("relationship"<|>"Projected Rise in Daytime Temperature"<|>"MIGP Region"<|>"Projected rise in daytime temperature during monsoon is higher in SP and MIGP as compared to UIGP region, even though minimum temperatures are projected to rise almost similarly in these locations."<|>"climate factor, location"<|>7)##
# ("relationship"<|>"Projected Rise in Daytime Temperature"<|>"UIGP Region"<|>"Projected rise in daytime temperature during monsoon is higher in SP and MIGP as compared to UIGP region, even though minimum temperatures are projected to rise almost similarly in these locations."<|>"climate factor, location"<|>6)##
# ("relationship"<|>"Projected Rise in Minimum Temperatures"<|>"SP Region"<|>"Projected rise in daytime temperature during monsoon is higher in SP and MIGP as compared to UIGP region, even though minimum temperatures are projected to rise almost similarly in these locations."<|>"climate factor, location"<|>6)##
# ("relationship"<|>"Projected Rise in Minimum Temperatures"<|>"MIGP Region"<|>"Projected rise in daytime temperature during monsoon is higher in SP and MIGP as compared to UIGP region, even though minimum temperatures are projected to rise almost similarly in these locations."<|>"climate factor, location"<|>6)##
# ("relationship"<|>"Projected Rise in Minimum Temperatures"<|>"UIGP Region"<|>"Projected rise in daytime temperature during monsoon is higher in SP and MIGP as compared to UIGP region, even though minimum temperatures are projected to rise almost similarly in these locations."<|>"climate factor, location"<|>6)##
# ("relationship"<|>"Projected Changes in Rainfall"<|>"UIGP Region"<|>"Apart from this, rainfall is projected to increase in UIGP while it is likely to change in MIGP."<|>"climate factor, location"<|>7)##
# ("relationship"<|>"Projected Changes in Rainfall"<|>"MIGP Region"<|>"Apart from this, rainfall is projected to increase in UIGP while it is likely to change in MIGP."<|>"climate factor, location"<|>7)##
# ("relationship"<|>"Spatio-Temporal Variation"<|>"Projected Changes in Temperature"<|>"Thus, the spatio-temporal variation in existing climatic conditions and projected changes in temperature and rainfall would bring about differential impacts on monsoon maize crop in India."<|>"factor, climate factor"<|>8)##
# ("relationship"<|>"Spatio-Temporal Variation"<|>"Projected Changes in Rainfall"<|>"Thus, the spatio-temporal variation in existing climatic conditions and projected changes in temperature and rainfall would bring about differential impacts on monsoon maize crop in India."<|>"factor, climate factor"<|>8)##
# ("relationship"<|>"Spatio-Temporal Variation"<|>"Monsoon Maize Crop in India"<|>"Thus, the spatio-temporal variation in existing climatic conditions and projected changes in temperature and rainfall would bring about differential impacts on monsoon maize crop in India."<|>"cause, impact"<|>9)##
# ("relationship"<|>"Projected Changes in Temperature"<|>"Monsoon Maize Crop in India"<|>"Thus, the spatio-temporal variation in existing climatic conditions and projected changes in temperature and rainfall would bring about differential impacts on monsoon maize crop in India."<|>"cause, impact"<|>8)##
# ("relationship"<|>"Projected Changes in Rainfall"<|>"Monsoon Maize Crop in India"<|>"Thus, the spatio-temporal variation in existing climatic conditions and projected changes in temperature and rainfall would bring about differential impacts on monsoon maize crop in India."<|>"cause, impact"<|>8)##
# ("relationship"<|>"Winter Maize Crop"<|>"~5% Yield Gains in UIGP by 2020"<|>"As far as maize crop grown in winter is concerned, yield gains are projected to be ~5% over current yield in 2020 scenario at UIGP and this benefit is likely to remain till 2050 (Fig. 4b)."<|>"crop type, yield gain"<|>8)##
# ("relationship"<|>"UIGP Region"<|>"~5% Yield Gains in UIGP by 2020"<|>"As far as maize crop grown in winter is concerned, yield gains are projected to be ~5% over current yield in 2020 scenario at UIGP and this benefit is likely to remain till 2050 (Fig. 4b)."<|>"location, yield gain"<|>8)##
# ("relationship"<|>"2020 Scenario"<|>"~5% Yield Gains in UIGP by 2020"<|>"As far as maize crop grown in winter is concerned, yield gains are projected to be ~5% over current yield in 2020 scenario at UIGP and this benefit is likely to remain till 2050 (Fig. 4b)."<|>"time, yield gain"<|>8)##
# ("relationship"<|>"UIGP Region"<|>"Winter Maize Yield Reduction by 25% in UIGP by 2080"<|>"However, in 2080 scenario, yields are projected to be reduced by 25% from current yields."<|>"location, yield loss"<|>8)##
# ("relationship"<|>"2080 Scenario"<|>"Winter Maize Yield Reduction by 25% in UIGP by 2080"<|>"However, in 2080 scenario, yields are projected to be reduced by 25% from current yields."<|>"time, yield loss"<|>8)##
# ("relationship"<|>"Winter Maize in MIGP"<|>"Winter Maize Yield Reduction by ~50% in MIGP by 2050"<|>"Winter maize in MIGP, currently a high yielding zone, is projected to suffer in post-2020 scenario."<|>"crop type, yield loss"<|>8)##
# ("relationship"<|>"MIGP Region"<|>"Winter Maize in MIGP"<|>"Winter maize in MIGP, currently a high yielding zone, is projected to suffer in post-2020 scenario."<|>"location, crop type"<|>7)##
# ("relationship"<|>"Winter Maize in MIGP"<|>"Winter Maize Yield Reduction by ~60% in MIGP by 2080"<|>"The reduction in yield is likely to be to the tune of ~50% by 2050 and about 60% by 2080."<|>"crop type, yield loss"<|>8)##
# ("relationship"<|>"MIGP Region"<|>"Winter Maize Yield Reduction by ~50% in MIGP by 2050"<|>"The reduction in yield is likely to be to the tune of ~50% by 2050 and about 60% by 2080."<|>"location, yield loss"<|>8)##
# ("relationship"<|>"MIGP Region"<|>"Winter Maize Yield Reduction by ~60% in MIGP by 2080"<|>"The reduction in yield is likely to be to the tune of ~50% by 2050 and about 60% by 2080."<|>"location, yield loss"<|>8)##
# ("relationship"<|>"2050 Scenario"<|>"Winter Maize Yield Reduction by ~50% in MIGP by 2050"<|>"The reduction in yield is likely to be to the tune of ~50% by 2050 and about 60% by 2080."<|>"time, yield loss"<|>8)##
# ("relationship"<|>"2080 Scenario"<|>"Winter Maize Yield Reduction by ~60% in MIGP by 2080"<|>"The reduction in yield is likely to be to the tune of ~50% by 2050 and about 60% by 2080."<|>"time, yield loss"<|>8)##
# ("relationship"<|>"Winter Maize in SP"<|>"Winter Maize Yield Decline by 13% in SP by 2020"<|>"In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080."<|>"crop type, yield loss"<|>8)##
# ("relationship"<|>"SP Region"<|>"Winter Maize in SP"<|>"In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080."<|>"location, crop type"<|>7)##
# ("relationship"<|>"Winter Maize in SP"<|>"Winter Maize Yield Decline by 17% in SP by 2050"<|>"In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080."<|>"crop type, yield loss"<|>8)##
# ("relationship"<|>"Winter Maize in SP"<|>"Winter Maize Yield Decline by 21% in SP by 2080"<|>"In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080."<|>"crop type, yield loss"<|>8)##
# ("relationship"<|>"SP Region"<|>"Winter Maize Yield Decline by 13% in SP by 2020"<|>"In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080."<|>"location, yield loss"<|>8)##
# ("relationship"<|>"SP Region"<|>"Winter Maize Yield Decline by 17% in SP by 2050"<|>"In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080."<|>"location, yield loss"<|>8)##
# ("relationship"<|>"SP Region"<|>"Winter Maize Yield Decline by 21% in SP by 2080"<|>"In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080."<|>"location, yield loss"<|>8)##
# ("relationship"<|>"2020 Scenario"<|>"Winter Maize Yield Decline by 13% in SP by 2020"<|>"In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080."<|>"time, yield loss"<|>8)##
# ("relationship"<|>"2050 Scenario"<|>"Winter Maize Yield Decline by 17% in SP by 2050"<|>"In SP region, yields are projected to decline by about 13% in 2020, 17% in 250 and 21% in 2080."<|>"time, yield loss"<|>8)##
# ("relationship"<|>"2080 Scenario"<|>"Winter Maize Yield Decline by 21% in SP by 2080"<|>"In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080."<|>"time, yield loss"<|>8)##
# ("relationship"<|>"Projected Rise in Temperature During Winter"<|>"UIGP Region"<|>"The projected rise in temperature during winter crop season is more in UIGP in 2020 and 2050 than in MIGP and SP, particularly during later part of crop growth."<|>"climate factor, location"<|>7)##
# ("relationship"<|>"Projected Rise in Temperature During Winter"<|>"2020 Scenario"<|>"The projected rise in temperature during winter crop season is more in UIGP in 2020 and 2050 than in MIGP and SP, particularly during later part of crop growth."<|>"climate factor, time"<|>7)##
# ("relationship"<|>"Projected Rise in Temperature During Winter"<|>"2050 Scenario"<|>"The projected rise in temperature during winter crop season is more in UIGP in 2020 and 2050 than in MIGP and SP, particularly during later part of crop growth."<|>"climate factor, time"<|>7)##
# ("relationship"<|>"Projected Rise in Temperature During Winter"<|>"MIGP Region"<|>"The projected rise in temperature during winter crop season is more in UIGP in 2020 and 2050 than in MIGP and SP, particularly during later part of crop growth."<|>"climate factor, location"<|>6)##
# ("relationship"<|>"Projected Rise in Temperature During Winter"<|>"SP Region"<|>"The projected rise in temperature during winter crop season is more in UIGP in 2020 and 2050 than in MIGP and SP, particularly during later part of crop growth."<|>"climate factor, location"<|>6)<|COMPLETE|>
# Entity extraction error: empty description for entity 'InfoCrop-MAIZE model' of type 'Experimental Design'
# Entity extraction error: empty description for entity 'Monsoon Crop' of type 'Experimental Design'
# Entity extraction error: empty description for entity 'Winter Crop' of type 'Experimental Design'

# %%
from utils import get_latest_result, read_knowledge_graph_from_pickle

# nodes, edges = get_latest_result()
nodes, edges = read_knowledge_graph_from_pickle("outputs/result_20250520_163337.pkl")

# %%
from operationCheatSheet import _link_relationships_across_entities
from openaillm import openai_embed

embedding_func = openai_embed

linkage_nodes, linkage_edges = await _link_relationships_across_entities(
    nodes, edges, embedding_func, nx_graph)

# %%
import networkx as nx

# Create a new graph
G = nx.Graph()

# Add edges with their attributes
for edge in linkage_edges:
    # Add edge with all attributes
    G.add_edge(
        edge['src_id'],
        edge['tgt_id'],
        description=edge['description'],
        keywords=edge['keywords'],
        source_id=edge['source_id'],
        file_path=edge['file_path']
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       4 G = nx.Graph()
#       6 # Add edges with their attributes
# ----> 7 for edge in linkage_edges:
#       8     # Add edge with all attributes
#       9     G.add_edge(
#      10         edge['src_id'],
#      11         edge['tgt_id'],
#    (...)     15         file_path=edge['file_path']
#      16     )
#
# NameError: name 'linkage_edges' is not defined

# %%
edge_description = [edge["description"] for edge in linkage_edges if edge["type"] == ('Climate Drivers', 'Crop Type')]

# %%
from rich.console import Console
from rich.text import Text

def highlight_with_rich(text, substrings, style="bold yellow"):
    console = Console()
    rich_text = Text(text)

    for substring in substrings:
        start = 0
        while True:
            index = text.find(substring[:40], start)
            if index == -1:
                break
            # Apply style to the substring
            rich_text.stylize(style, index, index + len(substring))
            start = index + len(substring)

    console.print(rich_text)

# edge_description = [edge["description"] for edge in linkage_edges if 'Crop Yield' in edge["type"]]
# node_description = [node["description"] for node in linkage_nodes if 'Crop Yield' in node["entity_type"]]

node_description = []
for node_list in nodes.values():
    for node in node_list:
        if 'Crop Yield' in node["entity_type"]:
            node_description.append(node["description"])


highlight_with_rich(content, node_description)
# Out:
# 3.1.1 Impact of fixed rise in temperature, CO₂ and change in rain fall
#
# Monsoon crop
# Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in
# atmospheric temperatures in all three regions (Fig. 2a). Grain yield decreased with each degree rise in atmospheric
# temperature. However, the rate of decrease varied with location. The mean baseline yield of rainfed maize crop is
# about 2 Mg ha⁻¹ in UIGP, where the projected yield loss is up to 7, 11, 15, 22, and 33% relative to baseline yields
# with 1, 2, 3, 4, 5°C degrees rise in atmospheric temperatures. However, a 20% increase in rainfall is projected to
# offset the yield loss due to 1°C rise in temperature. Similarly, a 30% increase in rainfall is predicted to offset
# the adverse impact of 2°C rise in temperature. In MIGP region, yield reduction of about 8–35% with 1–5°C rise in
# atmospheric temperature is projected. In this region, increase in rainfall is likely to offset the temperature rise
# up to 0.75°C and any increase beyond this temperature will adversely impact the yields, in spite of increase in
# rainfall. The SP region is also projected to experience adverse impact with -10, -15, -23, -27 and -35% reductions
# from the baseline yield levels at each 1°C rise in temperature. A 10% increase in rainfall will offset the
# reduction in yield due to 1°C rise in temperature in this region.
#
# Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1
# to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV. The benefits are projected to be high in mild water stress
# conditions, but they are likely to reduce in severe water stress situations (Table 3). The yield gains due to
# increase in atmospheric CO₂ concentration are projected to be more in SP regions (low rainfall area) followed by
# UIGP and MIGP regions.
#
# Winter crop
# Maize crop during winter is provided with assured irrigation and thus yields about 1.5 times more than that of
# monsoon crop. Winter maize grain yield reduced with increase in temperatures in SP and MIGP, but in UIGP rise in
# temperatures up to 2.7°C is likely to improve the maize yields. However, further increase in temperature is
# projected to reduce grain yields and the reductions are likely to be more than those at MIGP and SP (Fig. 3a). In
# UIGP, this beneficial effect with rise in temperature is projected to be more up to 2°C rise (13% increase over
# current yields). In this region, yield will improve with 2°C in spite of reduction in rainfall. In the event of
# further increase in temperature to about 2.7°C, the reduction in yields can be offset only if rainfall is increased
# or more irrigation is provided. With temperature rise, the crop experiences conditions closer to optimal
# temperature during grain development, benefiting grain number. Relatively low temperature during grain filling
# period required more days to satisfy thermal time requirement. However, in both MIGP and SP, where the average
# maximum temperatures during winter crop season are relatively higher (Table 2), any increase in temperature can
# cause reduction in yield.
#
# Table 3 Influence of atmospheric carbon dioxide concentration on maize yields in rainfall deficit conditions during
# monsoon season
#
# In UIGP, rise in temperatures beyond 2.7°C caused reduction in yield mainly due to reduced number of grains. This
# limited the gains in spite of increase in GFD and individual grain weight. Further increase in temperature resulted
# in yield reduction from current yields. In UIGP, GFD was found to increase with rise in temperature because of
# current lower temperature during winter. While the rise in temperature prolonged GFD significantly at UIGP than at
# MIGP, it actually reduced at SP. In all locations, flowering hastened due to increase in temperature.
# 3.1.2 Impact of climate change scenarios on maize yield
#
# The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂
# concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model. This approach was
# followed because of reported spatio-temporal variations in climate change scenarios (IPCC 2007).
#
# Monsoon crop
# The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity
# of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a). This is mainly due to projected increase in
# rainfall during crop season, which will provide scope for improved dry matter production and increase in grain
# number. This implies that the maize crop may benefit from additional availability of water in spite of increase in
# temperature and related reduction in crop duration by 3–4 days. On the other hand, in MIGP, maize is likely to
# suffer yield loss in future scenarios. The loss from current yields is projected to be ~5%, ~13%, ~17% in 2020,
# 2050 and 2080, respectively. In SP, monsoon season crop is projected to lose grain yield by 21% from current yields
# due to climate change by 2020 and 35% by 2050 and later. Projected rise in daytime temperature during monsoon is
# higher in SP and MIGP as compared to UIGP region, even though minimum temperatures are projected to rise almost
# similarly in these locations. Apart from this, rainfall is projected to increase in UIGP while it is likely to
# change in MIGP. Thus, the spatio-temporal variation in existing climatic conditions and projected changes in
# temperature and rainfall would bring about differential impacts on monsoon maize crop in India.
#
# Winter crop
# As far as maize crop grown in winter is concerned, yield gains are projected to be ~5% over current yield in 2020
# scenario at UIGP and this benefit is likely to remain till 2050 (Fig. 4b). However, in 2080 scenario, yields are
# projected to be reduced by 25% from current yields. Winter maize in MIGP, currently a high yielding zone, is
# projected to suffer in post-2020 scenario. The reduction in yield is likely to be to the tune of ~50% by 2050 and
# about 60% by 2080. In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080.
# In these areas, winter maize is well irrigated and thus variation in winter rainfall, which otherwise is low, is
# less influential. The projected rise in temperature during winter crop season is more in UIGP in 2020 and 2050 than
# in MIGP and SP, particularly during later part of crop growth.

# %%
edge_description = []
for edge_list in edges.values():
    for edge in edge_list:
        edge_src_id = edge["src_id"]
        edge_tgt_id = edge["tgt_id"]
        if edge_src_id in nodes.keys() and edge_tgt_id in nodes.keys():
            if 'Climate Drivers' in nodes[edge_src_id][0]["entity_type"] and 'Crop Yield' in nodes[edge_tgt_id][0]["entity_type"]:
                edge_description.append((edge_src_id, edge_tgt_id, edge["description"]))
            elif 'Climate Drivers' in nodes[edge_tgt_id][0]["entity_type"] and 'Crop Yield' in nodes[edge_src_id][0]["entity_type"]:
                edge_description.append((edge_tgt_id, edge_src_id, edge["description"]))

edge_description
# Out:
# [('Atmospheric Temperatures',
#   'Maize Yields',
#   'Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a).'),
#  ('1, 2, 3, 4, 5°C Degrees Rise',
#   'Projected Yield Loss in UIGP (7-33%)',
#   'The mean baseline yield of rainfed maize crop is about 2 Mg ha⁻¹ in UIGP, where the projected yield loss is up to 7, 11, 15, 22, and 33% relative to baseline yields with 1, 2, 3, 4, 5°C degrees rise in atmospheric temperatures.'),
#  ('1, 2, 3, 4, 5°C Degrees Rise',
#   'Yield Reduction of 8–35%',
#   'In MIGP region, yield reduction of about 8–35% with 1–5°C rise in atmospheric temperature is projected.'),
#  ('1°C Rise in Temperature',
#   'Projected Yield Reductions in SP (-10 to -35%)',
#   'The SP region is also projected to experience adverse impact with -10, -15, -23, -27 and -35% reductions from the baseline yield levels at each 1°C rise in temperature.'),
#  ('Increase in Carbon Dioxide',
#   'Projected Yield Benefit from CO₂ (0.1 to 7.2%)',
#   'Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV.'),
#  ('450 ppmV CO₂',
#   'Projected Yield Benefit from CO₂ (0.1 to 7.2%)',
#   'Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV.'),
#  ('550 ppmV CO₂',
#   'Projected Yield Benefit from CO₂ (0.1 to 7.2%)',
#   'Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV.'),
#  ('Mild Water Stress Conditions',
#   'Projected Yield Benefit from CO₂ (0.1 to 7.2%)',
#   'The benefits are projected to be high in mild water stress conditions, but they are likely to reduce in severe water stress situations (Table 3).'),
#  ('Severe Water Stress Situations',
#   'Projected Yield Benefit from CO₂ (0.1 to 7.2%)',
#   'The benefits are projected to be high in mild water stress conditions, but they are likely to reduce in severe water stress situations (Table 3).'),
#  ('Temperature',
#   'Winter Maize Grain Yield',
#   'Winter maize grain yield reduced with increase in temperatures in SP and MIGP, but in UIGP rise in temperatures up to 2.7°C is likely to improve the maize yields.'),
#  ('2°C Rise in Temperature',
#   '13% Increase Over Current Yields in UIGP',
#   'In UIGP, this beneficial effect with rise in temperature is projected to be more up to 2°C rise (13% increase over current yields).'),
#  ('Temperatures Beyond 2.7°C',
#   'Yield Reduction in UIGP Beyond 2.7°C',
#   'In UIGP, rise in temperatures beyond 2.7°C caused reduction in yield mainly due to reduced number of grains.'),
#  ('Rainfall',
#   'Maize Yields',
#   'However, a 20% increase in rainfall is projected to offset the yield loss due to 1°C rise in temperature.'),
#  ('Carbon Dioxide',
#   'Maize Yields',
#   'Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV.'),
#  ('Atmospheric Temperatures',
#   'Maize Yield',
#   'Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a).'),
#  ('1, 2, 3, 4, 5°C Rise in Temperature',
#   '7, 11, 15, 22, and 33% Yield Loss',
#   'The mean baseline yield of rainfed maize crop is about 2 Mg ha⁻¹ in UIGP, where the projected yield loss is up to 7, 11, 15, 22, and 33% relative to baseline yields with 1, 2, 3, 4, 5°C degrees rise in atmospheric temperatures.'),
#  ('20% Increase in Rainfall',
#   'Projected Yield Loss',
#   'However, a 20% increase in rainfall is projected to offset the yield loss due to 1°C rise in temperature.'),
#  ('30% Increase in Rainfall',
#   'Yield Reduction',
#   'Similarly, a 30% increase in rainfall is predicted to offset the adverse impact of 2°C rise in temperature.'),
#  ('1–5°C Rise in Temperature',
#   '8–35% Yield Reduction',
#   'In MIGP region, yield reduction of about 8–35% with 1–5°C rise in atmospheric temperature is projected.'),
#  ('Rainfall',
#   'Maize Yield',
#   'In this region, increase in rainfall is likely to offset the temperature rise up to 0.75°C and any increase beyond this temperature will adversely impact the yields, in spite of increase in rainfall.'),
#  ('1°C Rise in Temperature',
#   '-10, -15, -23, -27 and -35% Yield Reductions',
#   'The SP region is also projected to experience adverse impact with -10, -15, -23, -27 and -35% reductions from the baseline yield levels at each 1°C rise in temperature.'),
#  ('10% Increase in Rainfall',
#   'Yield Reduction',
#   'A 10% increase in rainfall will offset the reduction in yield due to 1°C rise in temperature in this region.'),
#  ('Increase in Carbon Dioxide',
#   'Maize Yield',
#   'Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV.'),
#  ('450 ppmV CO₂',
#   '0.1 to 3.4% Yield Increase',
#   'increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV.'),
#  ('550 ppmV CO₂',
#   '0.6 to 7.2% Yield Increase',
#   'increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV.'),
#  ('Mild Water Stress Conditions',
#   'Yield Gains',
#   'The benefits are projected to be high in mild water stress conditions, but they are likely to reduce in severe water stress situations (Table 3).'),
#  ('Severe Water Stress Situations',
#   'Yield Gains',
#   'The benefits are projected to be high in mild water stress conditions, but they are likely to reduce in severe water stress situations (Table 3).'),
#  ('Atmospheric CO₂ Concentration',
#   'Yield Gains',
#   'The yield gains due to increase in atmospheric CO₂ concentration are projected to be more in SP regions (low rainfall area) followed by UIGP and MIGP regions.'),
#  ('Increase in Temperatures',
#   'Grain Yield',
#   'Winter maize grain yield reduced with increase in temperatures in SP and MIGP, but in UIGP rise in temperatures up to 2.7°C is likely to improve the maize yields.'),
#  ('2.7°C Rise in Temperature',
#   'Grain Yield',
#   'but in UIGP rise in temperatures up to 2.7°C is likely to improve the maize yields.'),
#  ('2°C Rise in Temperature',
#   '13% Increase in Yield',
#   'In UIGP, this beneficial effect with rise in temperature is projected to be more up to 2°C rise (13% increase over current yields).'),
#  ('Rainfall',
#   'Yield Reduction',
#   'In the event of further increase in temperature to about 2.7°C, the reduction in yields can be offset only if rainfall is increased or more irrigation is provided.'),
#  ('Increase in Temperatures',
#   'Yield Reduction',
#   'However, in both MIGP and SP, where the average maximum temperatures during winter crop season are relatively higher (Table 2), any increase in temperature can cause reduction in yield.'),
#  ('Increase in Temperature',
#   'GFD',
#   'In UIGP, GFD was found to increase with rise in temperature because of current lower temperature during winter.'),
#  ('Increase in Rainfall',
#   'Dry Matter Production',
#   'This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number.'),
#  ('Increase in Rainfall',
#   'Grain Number',
#   'This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number.'),
#  ('Each Degree Rise in Atmospheric Temperature',
#   'Grain Yield',
#   'Grain yield decreased with each degree rise in atmospheric temperature.'),
#  ('1, 2, 3, 4, 5°C Degrees Rise in Atmospheric Temperatures',
#   'Projected Yield Loss (7, 11, 15, 22, 33%)',
#   'The mean baseline yield of rainfed maize crop is about 2 Mg ha⁻¹ in UIGP, where the projected yield loss is up to 7, 11, 15, 22, and 33% relative to baseline yields with 1, 2, 3, 4, 5°C degrees rise in atmospheric temperatures.'),
#  ('20% Increase in Rainfall',
#   'Yield Loss',
#   'However, a 20% increase in rainfall is projected to offset the yield loss due to 1°C rise in temperature.'),
#  ('1–5°C Rise in Atmospheric Temperature',
#   'Yield Reduction (8–35%)',
#   'In MIGP region, yield reduction of about 8–35% with 1–5°C rise in atmospheric temperature is projected.'),
#  ('Increase in Rainfall',
#   'Yields',
#   'In this region, increase in rainfall is likely to offset the temperature rise up to 0.75°C and any increase beyond this temperature will adversely impact the yields, in spite of increase in rainfall.'),
#  ('Each 1°C Rise in Temperature',
#   '-10, -15, -23, -27 and -35% Reductions',
#   'The SP region is also projected to experience adverse impact with -10, -15, -23, -27 and -35% reductions from the baseline yield levels at each 1°C rise in temperature.'),
#  ('10% Increase in Rainfall',
#   'Reduction in Yield',
#   'A 10% increase in rainfall will offset the reduction in yield due to 1°C rise in temperature in this region.'),
#  ('Increase in Carbon Dioxide',
#   'Crop Yield Benefit (0.1 to 7.2%)',
#   'Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV.'),
#  ('Mild Water Stress Conditions',
#   'Crop Yield Benefit (0.1 to 7.2%)',
#   'The benefits are projected to be high in mild water stress conditions, but they are likely to reduce in severe water stress situations (Table 3).'),
#  ('Severe Water Stress Situations',
#   'Crop Yield Benefit (0.1 to 7.2%)',
#   'The benefits are projected to be high in mild water stress conditions, but they are likely to reduce in severe water stress situations (Table 3).'),
#  ('Increase in Atmospheric CO₂ Concentration',
#   'Yield Gains',
#   'The yield gains due to increase in atmospheric CO₂ concentration are projected to be more in SP regions (low rainfall area) followed by UIGP and MIGP regions.'),
#  ('Increase in Temperatures',
#   'Winter Maize Grain Yield',
#   'Winter maize grain yield reduced with increase in temperatures in SP and MIGP, but in UIGP rise in temperatures up to 2.7°C is likely to improve the maize yields.'),
#  ('Rise in Temperatures Up to 2.7°C',
#   'Winter Maize Grain Yield',
#   'Winter maize grain yield reduced with increase in temperatures in SP and MIGP, but in UIGP rise in temperatures up to 2.7°C is likely to improve the maize yields.'),
#  ('2°C Rise',
#   '13% Increase Over Current Yields',
#   'In UIGP, this beneficial effect with rise in temperature is projected to be more up to 2°C rise (13% increase over current yields).'),
#  ('Increase in Temperature',
#   'Reduction in Yield',
#   'However, in both MIGP and SP, where the average maximum temperatures during winter crop season are relatively higher (Table 2), any increase in temperature can cause reduction in yield.'),
#  ('Rise in Temperatures Beyond 2.7°C',
#   'Reduction in Yield',
#   'In UIGP, rise in temperatures beyond 2.7°C caused reduction in yield mainly due to reduced number of grains.'),
#  ('Climate Change',
#   'Productivity of Monsoon Maize Crop',
#   'The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a).'),
#  ('Increase In Rainfall',
#   'Increase In Grain Number',
#   'This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number.'),
#  ('Increase In Rainfall',
#   'Insignificant Productivity Effect',
#   'This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number.'),
#  ('Climate Change',
#   '21% Grain Yield Loss',
#   'In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later.'),
#  ('Climate Change',
#   '35% Yield Loss',
#   'In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later.'),
#  ('Climate Change',
#   'Yield Insignificantly Affected in UIGP (Monsoon)',
#   'The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a).'),
#  ('Projected Increase in Rainfall',
#   'Yield Insignificantly Affected in UIGP (Monsoon)',
#   'This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number.'),
#  ('Climate Change',
#   'Yield Loss in MIGP (Monsoon)',
#   'On the other hand, in MIGP, maize is likely to suffer yield loss in future scenarios.'),
#  ('Climate Change',
#   'Grain Yield Loss in SP (Monsoon)',
#   'In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later.'),
#  ('Climate Change',
#   'Insignificantly Affect The Productivity',
#   'The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a).'),
#  ('Projected Increase In Rainfall',
#   'Improved Dry Matter Production',
#   'This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number.'),
#  ('Projected Increase In Rainfall',
#   'Increase In Grain Number',
#   'This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number.'),
#  ('Climate Change',
#   'Lose Grain Yield By 21%',
#   'In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later.'),
#  ('Climate Change',
#   '35% Loss',
#   'In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later.'),
#  ('Spatio-Temporal Variation In Existing Climatic Conditions',
#   'Differential Impacts',
#   'Thus, the spatio-temporal variation in existing climatic conditions and projected changes in temperature and rainfall would bring about differential impacts on monsoon maize crop in India.'),
#  ('Projected Changes In Temperature And Rainfall',
#   'Differential Impacts',
#   'Thus, the spatio-temporal variation in existing climatic conditions and projected changes in temperature and rainfall would bring about differential impacts on monsoon maize crop in India.')]

# %%
nodes['Maize'][0]
# Out:
# {'entity_name': 'Maize',
#  'entity_type': 'Crop Type',
#  'description': 'Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a).',
#  'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#  'file_path': 'example.txt'}
