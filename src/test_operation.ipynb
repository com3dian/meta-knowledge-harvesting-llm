# %%
from operations import extract_entities

import networkx as nx
from cheatsheet import CHEATSHEETS

def create_cheatsheet_knowledge_graph() -> nx.Graph:
    """
    Creates a NetworkX graph from the cheatsheet relationships.
    Returns:
        nx.Graph: Graph containing entity types as nodes and their relationships
    """
    G = nx.Graph()
    
    # Parse the cheatsheet relationships
    relationships = CHEATSHEETS["cheat_sheet_kg"].strip().split('\n')
    for relationship in relationships:
        if not relationship.strip():
            continue
            
        # Split on "-" and clean up whitespace
        nodes = [node.strip() for node in relationship.strip(';').split('-')]
        if len(nodes) == 2:
            source, target = nodes
            # Add nodes and edge
            G.add_node(source)
            G.add_node(target)
            G.add_edge(
                source, 
                target,
                description=f"Relationship between {source} and {target}",
                weight=1.0
            )
    
    return G
nx_graph = create_cheatsheet_knowledge_graph()

# %%
nx_graph.nodes()
# Out:
# NodeView(('Crop Type', 'Crop Yield', 'Climate Drivers', 'Experimental Design', 'Location', 'Time'))

# %%
content = """
3.1.1 Impact of fixed rise in temperature, CO₂ and change in rain fall

Monsoon crop
Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a). Grain yield decreased with each degree rise in atmospheric temperature. However, the rate of decrease varied with location. The mean baseline yield of rainfed maize crop is about 2 Mg ha⁻¹ in UIGP, where the projected yield loss is up to 7, 11, 15, 22, and 33% relative to baseline yields with 1, 2, 3, 4, 5°C degrees rise in atmospheric temperatures. However, a 20% increase in rainfall is projected to offset the yield loss due to 1°C rise in temperature. Similarly, a 30% increase in rainfall is predicted to offset the adverse impact of 2°C rise in temperature. In MIGP region, yield reduction of about 8–35% with 1–5°C rise in atmospheric temperature is projected. In this region, increase in rainfall is likely to offset the temperature rise up to 0.75°C and any increase beyond this temperature will adversely impact the yields, in spite of increase in rainfall. The SP region is also projected to experience adverse impact with -10, -15, -23, -27 and -35% reductions from the baseline yield levels at each 1°C rise in temperature. A 10% increase in rainfall will offset the reduction in yield due to 1°C rise in temperature in this region.

Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV. The benefits are projected to be high in mild water stress conditions, but they are likely to reduce in severe water stress situations (Table 3). The yield gains due to increase in atmospheric CO₂ concentration are projected to be more in SP regions (low rainfall area) followed by UIGP and MIGP regions.

Winter crop
Maize crop during winter is provided with assured irrigation and thus yields about 1.5 times more than that of monsoon crop. Winter maize grain yield reduced with increase in temperatures in SP and MIGP, but in UIGP rise in temperatures up to 2.7°C is likely to improve the maize yields. However, further increase in temperature is projected to reduce grain yields and the reductions are likely to be more than those at MIGP and SP (Fig. 3a). In UIGP, this beneficial effect with rise in temperature is projected to be more up to 2°C rise (13% increase over current yields). In this region, yield will improve with 2°C in spite of reduction in rainfall. In the event of further increase in temperature to about 2.7°C, the reduction in yields can be offset only if rainfall is increased or more irrigation is provided. With temperature rise, the crop experiences conditions closer to optimal temperature during grain development, benefiting grain number. Relatively low temperature during grain filling period required more days to satisfy thermal time requirement. However, in both MIGP and SP, where the average maximum temperatures during winter crop season are relatively higher (Table 2), any increase in temperature can cause reduction in yield.

Table 3 Influence of atmospheric carbon dioxide concentration on maize yields in rainfall deficit conditions during monsoon season

In UIGP, rise in temperatures beyond 2.7°C caused reduction in yield mainly due to reduced number of grains. This limited the gains in spite of increase in GFD and individual grain weight. Further increase in temperature resulted in yield reduction from current yields. In UIGP, GFD was found to increase with rise in temperature because of current lower temperature during winter. While the rise in temperature prolonged GFD significantly at UIGP than at MIGP, it actually reduced at SP. In all locations, flowering hastened due to increase in temperature.
3.1.2 Impact of climate change scenarios on maize yield

The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model. This approach was followed because of reported spatio-temporal variations in climate change scenarios (IPCC 2007).

Monsoon crop
The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a). This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number. This implies that the maize crop may benefit from additional availability of water in spite of increase in temperature and related reduction in crop duration by 3–4 days. On the other hand, in MIGP, maize is likely to suffer yield loss in future scenarios. The loss from current yields is projected to be ~5%, ~13%, ~17% in 2020, 2050 and 2080, respectively. In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later. Projected rise in daytime temperature during monsoon is higher in SP and MIGP as compared to UIGP region, even though minimum temperatures are projected to rise almost similarly in these locations. Apart from this, rainfall is projected to increase in UIGP while it is likely to change in MIGP. Thus, the spatio-temporal variation in existing climatic conditions and projected changes in temperature and rainfall would bring about differential impacts on monsoon maize crop in India.

Winter crop
As far as maize crop grown in winter is concerned, yield gains are projected to be ~5% over current yield in 2020 scenario at UIGP and this benefit is likely to remain till 2050 (Fig. 4b). However, in 2080 scenario, yields are projected to be reduced by 25% from current yields. Winter maize in MIGP, currently a high yielding zone, is projected to suffer in post-2020 scenario. The reduction in yield is likely to be to the tune of ~50% by 2050 and about 60% by 2080. In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080. In these areas, winter maize is well irrigated and thus variation in winter rainfall, which otherwise is low, is less influential. The projected rise in temperature during winter crop season is more in UIGP in 2020 and 2050 than in MIGP and SP, particularly during later part of crop growth.
"""

# %%
import asyncio
import os
from dotenv import load_dotenv
from operations import chunking_by_token_size, extract_entities
from utils import compute_mdhash_id
from llm_impl.geminillm import gemini_complete_if_cache
from llm_impl.openaillm import openai_embed, openai_complete
from database_impl.faiss_impl import FaissVectorDBStorage
from database_impl.networkx_impl import NetworkXStorage
from database_impl.json_kv_iml import JsonKVStorage
from database_impl.shared_storage import initialize_share_data
from cheatsheet import CHEATSHEETS
from grobidmonkey import reader

# LLM_MODEL_NAME = "gpt-3.5-turbo"
LLM_MODEL_NAME = "gemini-2.5-flash-preview-05-20"

load_dotenv()

async def process_text_to_knowledge_graph(text_content,
                                          cheatsheet_knowledge_graph_inst,
                                          file_path="unknown_source"):
    # Step 1: Create chunks from your text content
    raw_chunks = chunking_by_token_size(
        content=text_content,
        split_by_character=None,  # Optional: specify a character to split by (e.g., "\n\n")
        split_by_character_only=False,
        overlap_token_size=128,
        max_token_size=1024,
        tiktoken_model=LLM_MODEL_NAME
    )
    
    # Step 2: Format chunks as required by extract_entities
    doc_id = compute_mdhash_id(text_content, prefix="doc-")
    chunks = {
        compute_mdhash_id(chunk["content"], prefix="chunk-"): {
            **chunk,
            "full_doc_id": doc_id,
            "file_path": file_path
        }
        for chunk in raw_chunks
    }
    
    # Step 3: Initialize your storage instances
    faiss_global_config = {
        "working_dir": "/tmp",
        "embedding_batch_num": 64,  # or another integer suitable for your setup
        "vector_db_storage_cls_kwargs": {
            "cosine_better_than_threshold": 0.2  # or another float threshold you want
        },
        "base_url": "https://api.openai.com/v1",
    }
    kv_global_config = {
        "working_dir": "/tmp",
        "llm_model_name": LLM_MODEL_NAME,
        "embedding_batch_num": 64,  # or another integer suitable for your setup
        "vector_db_storage_cls_kwargs": {
            "cosine_better_than_threshold": 0.2  # or another float threshold you want
        },
        "base_url": "https://api.openai.com/v1",
    }
    knowledge_graph = NetworkXStorage(namespace="nx_kg", global_config=faiss_global_config, embedding_func=openai_embed)  # Graph storage implementation
    entity_vector_db = FaissVectorDBStorage(namespace="faiss_entity", global_config=faiss_global_config, embedding_func=openai_embed)  # Vector storage for entities
    relationship_vector_db = FaissVectorDBStorage(namespace="faiss_relationship", global_config=faiss_global_config, embedding_func=openai_embed)  # Vector storage for relationships
    llm_cache = JsonKVStorage(namespace="llm_cache", global_config=kv_global_config, embedding_func=openai_embed)
    
    initialize_share_data()

    await knowledge_graph.initialize()
    await entity_vector_db.initialize()
    await relationship_vector_db.initialize()
    await llm_cache.initialize()  # if your cache supports/needs it

    # Step 4: Use the Gemini LLM function from openai.py
    # Create a wrapper that matches the expected signature for extract_entities
    async def llm_wrapper(prompt, history_messages=None, max_tokens=None, **kwargs):
        if history_messages is None:
            history_messages = []
    

        # Use Google GenAI
        return await asyncio.to_thread(
            gemini_complete_if_cache,
            model=LLM_MODEL_NAME,
            prompt=prompt,
            history_messages=history_messages,
            hashing_kv=llm_cache,
            temperature=0.2,
            max_tokens=max_tokens or 1024,
        )

    entity_cheatsheet_dict = {
        "Crop Type": "The crop type, including the full name and abbreviations of the crop type.",
        "Crop Yield": "The numerical value crop yield, including the values of the crop yield and their units, percentage value of crop yield, or the difference of crop yield between two conditions."
                      "E.g. 10% increase in crop yield, 10% decrease in rice yield, 10% increase in wheat yield compared to the control group, 10% decrease in maize yield compared to the control group.",
        "Climate Drivers": "The climate drivers such as temperature, water availability and CO2 concentration, including the values of the climate drivers and their units, or percentage value of climate drivers.",
        "Experimental Design": "The full name and abbreviations of the experimental design, or the scenario of the experiment.",
        "Location": "The location of the experiment, including the full name and abbreviations of the location, or the latitude and longitude of the location.",
        "Time": "The time of the experiment, including day, month, year, the duration of the experiment, or the timing of exposure to stress—especially during critical developmental phases.",
    }
    
    # Step 5: Configure the extraction process
    global_config = {
        "llm_model_func": llm_wrapper,  # Use our wrapper function
        "llm_model_name": LLM_MODEL_NAME,  # Required for some OpenAI functions
        "entity_extract_max_gleaning": 2,
        "force_llm_summary_on_merge": False,
        "llm_model_max_token_size": 1024,
        "summary_to_max_tokens": 256,
        "tiktoken_model_name": LLM_MODEL_NAME,
        "addon_params": {
            "language": "English",
            "entity_types": list(entity_cheatsheet_dict.keys())
        },
    }
    
    # Step 6: Optional status tracking
    pipeline_status = {
        "latest_message": "",
        "history_messages": []
    }
    pipeline_status_lock = asyncio.Lock()
    
    # Step 7: Run the extraction
    await extract_entities(
        chunks=chunks,
        entity_cheatsheet_dict=entity_cheatsheet_dict,
        knowledge_graph_inst=knowledge_graph,
        entity_vdb=entity_vector_db,
        relationships_vdb=relationship_vector_db,
        global_config=global_config,
        pipeline_status=pipeline_status,
        pipeline_status_lock=pipeline_status_lock,
        llm_response_cache=llm_cache,
        cheatsheet_knowledge_graph_inst=cheatsheet_knowledge_graph_inst,
        write_result_to_txt=True
    )
    
    return knowledge_graph

# Example usage in a Jupyter notebook
async def main():
    # monkeyReader = reader.MonkeyReader('monkey') # or 'lxml' or 'x2d'

    # read paper content
    # essay = monkeyReader.readEssay('./xmldata/Byjesh.pdf.tei.xml')
    # text = "\n".join(essay["Impact of fixed rise in temperature, CO 2 and change in rain fall"])
    text = content
    knowledge_graph = await process_text_to_knowledge_graph(text, nx_graph, "example.txt")
    # Now you can query the knowledge graph for entities and relationships
    
    return knowledge_graph

# In a Jupyter notebook, you can run this with:
knowledge_graph = await main()
# Out:
# No existing Faiss index file found. Starting fresh.
# No existing Faiss index file found. Starting fresh.
# INFO: Process 182524 Shared-Data created for Single Process
# INFO: Process 182524 initialized updated flags for namespace: [nx_kg]
# INFO: Process 182524 initialized updated flags for namespace: [faiss_entity]
# INFO: Process 182524 initialized updated flags for namespace: [faiss_relationship]
# INFO: Process 182524 initialized updated flags for namespace: [llm_cache]
# INFO: Process 182524 ready to initialize storage namespace: [llm_cache]
# /home/com3dian/Github/meta-knowledge-harvesting-llm/src/operations.py:733: RuntimeWarning: coroutine 'extract_entities.<locals>.nightly_kg_to_text' was never awaited
#   hint_prompt = fill_nightly_prompt.format(
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
from utils import get_latest_result, read_knowledge_graph_from_pickle

nodes, edges = get_latest_result()

# %%
# Out:
# defaultdict(list,
#             {'Maize': [{'entity_name': 'Maize',
#                'entity_type': 'Crop Type',
#                'description': 'Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a). Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'},
#               {'entity_name': 'Maize',
#                'entity_type': 'Crop Type',
#                'description': 'The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Mean Baseline Yield Of Rainfed Maize': [{'entity_name': 'Mean Baseline Yield Of Rainfed Maize',
#                'entity_type': 'Crop Yield',
#                'description': 'The mean baseline yield of rainfed maize crop is about 2 Mg ha⁻¹ in UIGP, where the projected yield loss is up to 7, 11, 15, 22, and 33% relative to baseline yields with 1, 2, 3, 4, 5°C degrees rise in atmospheric temperatures.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Yield Loss Due To Temperature Rise': [{'entity_name': 'Yield Loss Due To Temperature Rise',
#                'entity_type': 'Crop Yield',
#                'description': 'The mean baseline yield of rainfed maize crop is about 2 Mg ha⁻¹ in UIGP, where the projected yield loss is up to 7, 11, 15, 22, and 33% relative to baseline yields with 1, 2, 3, 4, 5°C degrees rise in atmospheric temperatures. In MIGP region, yield reduction of about 8–35% with 1–5°C rise in atmospheric temperature is projected.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Yield Gain Due To CO₂ Increase': [{'entity_name': 'Yield Gain Due To CO₂ Increase',
#                'entity_type': 'Crop Yield',
#                'description': 'Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV. The yield gains due to increase in atmospheric CO₂ concentration are projected to be more in SP regions (low rainfall area) followed by UIGP and MIGP regions.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Monsoon Maize Yield': [{'entity_name': 'Monsoon Maize Yield',
#                'entity_type': 'Crop Yield',
#                'description': 'Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a). The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Winter Maize Yield': [{'entity_name': 'Winter Maize Yield',
#                'entity_type': 'Crop Yield',
#                'description': 'Maize crop during winter is provided with assured irrigation and thus yields about 1.5 times more than that of monsoon crop. In UIGP, this beneficial effect with rise in temperature is projected to be more up to 2°C rise (13% increase over current yields).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Atmospheric Temperature Increase': [{'entity_name': 'Atmospheric Temperature Increase',
#                'entity_type': 'Climate Drivers',
#                'description': 'Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a). Grain yield decreased with each degree rise in atmospheric temperature.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Rainfall Increase': [{'entity_name': 'Rainfall Increase',
#                'entity_type': 'Climate Drivers',
#                'description': 'However, a 20% increase in rainfall is projected to offset the yield loss due to 1°C rise in temperature. Similarly, a 30% increase in rainfall is predicted to offset the adverse impact of 2°C rise in temperature.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Atmospheric CO₂ Concentration Increase': [{'entity_name': 'Atmospheric CO₂ Concentration Increase',
#                'entity_type': 'Climate Drivers',
#                'description': 'Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV. The yield gains due to increase in atmospheric CO₂ concentration are projected to be more in SP regions (low rainfall area) followed by UIGP and MIGP regions.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Water Stress Conditions': [{'entity_name': 'Water Stress Conditions',
#                'entity_type': 'Climate Drivers',
#                'description': 'The benefits are projected to be high in mild water stress conditions, but they are likely to reduce in severe water stress situations (Table 3).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Simulation Analysis': [{'entity_name': 'Simulation Analysis',
#                'entity_type': 'Experimental Design',
#                'description': 'Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Climate Change Scenarios': [{'entity_name': 'Climate Change Scenarios',
#                'entity_type': 'Experimental Design',
#                'description': 'The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model. This approach was followed because of reported spatio-temporal variations in climate change scenarios (IPCC 2007).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'HadCM3 Model': [{'entity_name': 'HadCM3 Model',
#                'entity_type': 'Experimental Design',
#                'description': 'The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Bern CC Model': [{'entity_name': 'Bern CC Model',
#                'entity_type': 'Experimental Design',
#                'description': 'The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'InfoCrop-MAIZE Model': [{'entity_name': 'InfoCrop-MAIZE Model',
#                'entity_type': 'Experimental Design',
#                'description': 'The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'},
#               {'entity_name': 'InfoCrop-MAIZE Model',
#                'entity_type': 'Experimental Design',
#                'description': 'This approach was followed because of reported spatio-temporal variations in climate change scenarios (IPCC 2007).',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'UIGP': [{'entity_name': 'UIGP',
#                'entity_type': 'Location',
#                'description': 'The mean baseline yield of rainfed maize crop is about 2 Mg ha⁻¹ in UIGP, where the projected yield loss is up to 7, 11, 15, 22, and 33% relative to baseline yields with 1, 2, 3, 4, 5°C degrees rise in atmospheric temperatures. In UIGP, rise in temperatures beyond 2.7°C caused reduction in yield mainly due to reduced number of grains.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'MIGP': [{'entity_name': 'MIGP',
#                'entity_type': 'Location',
#                'description': 'In MIGP region, yield reduction of about 8–35% with 1–5°C rise in atmospheric temperature is projected. In this region, increase in rainfall is likely to offset the temperature rise up to 0.75°C and any increase beyond this temperature will adversely impact the yields, in spite of increase in rainfall.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'},
#               {'entity_name': 'MIGP',
#                'entity_type': 'MIGP',
#                'description': 'Location',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'SP Region': [{'entity_name': 'SP Region',
#                'entity_type': 'Location',
#                'description': 'The SP region is also projected to experience adverse impact with -10, -15, -23, -27 and -35% reductions from the baseline yield levels at each 1°C rise in temperature. The yield gains due to increase in atmospheric CO₂ concentration are projected to be more in SP regions (low rainfall area) followed by UIGP and MIGP regions.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'},
#               {'entity_name': 'SP Region',
#                'entity_type': 'Location',
#                'description': 'In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Monsoon Season': [{'entity_name': 'Monsoon Season',
#                'entity_type': 'Time',
#                'description': 'Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a). The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Winter Crop Season': [{'entity_name': 'Winter Crop Season',
#                'entity_type': 'Time',
#                'description': 'Maize crop during winter is provided with assured irrigation and thus yields about 1.5 times more than that of monsoon crop. However, in both MIGP and SP, where the average maximum temperatures during winter crop season are relatively higher (Table 2), any increase in temperature can cause reduction in yield.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'},
#               {'entity_name': 'Winter Crop Season',
#                'entity_type': 'Time',
#                'description': 'The projected rise in temperature during winter crop season is more in UIGP in 2020 and 2050 than in MIGP and SP, particularly during later part of crop growth.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Year 2020': [{'entity_name': 'Year 2020',
#                'entity_type': 'Time',
#                'description': 'The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Year 2050': [{'entity_name': 'Year 2050',
#                'entity_type': 'Time',
#                'description': 'The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Year 2080': [{'entity_name': 'Year 2080',
#                'entity_type': 'Time',
#                'description': 'The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Monsoon Maize Season': [{'entity_name': 'Monsoon Maize Season',
#                'entity_type': 'Time',
#                'description': 'Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Winter Maize Season': [{'entity_name': 'Winter Maize Season',
#                'entity_type': 'Time',
#                'description': 'Maize crop during winter is provided with assured irrigation and thus yields about 1.5 times more than that of monsoon crop.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Maize Yields in Monsoon Season': [{'entity_name': 'Maize Yields in Monsoon Season',
#                'entity_type': 'Crop Yield',
#                'description': 'Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Atmospheric Temperatures': [{'entity_name': 'Atmospheric Temperatures',
#                'entity_type': 'Climate Drivers',
#                'description': 'Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Baseline Rainfed Maize Yield (UIGP)': [{'entity_name': 'Baseline Rainfed Maize Yield (UIGP)',
#                'entity_type': 'Crop Yield',
#                'description': 'The mean baseline yield of rainfed maize crop is about 2 Mg ha⁻¹ in UIGP, where the projected yield loss is up to 7, 11, 15, 22, and 33% relative to baseline yields with 1, 2, 3, 4, 5°C degrees rise in atmospheric temperatures.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Maize Yield Loss (UIGP Monsoon)': [{'entity_name': 'Maize Yield Loss (UIGP Monsoon)',
#                'entity_type': 'Crop Yield',
#                'description': 'The mean baseline yield of rainfed maize crop is about 2 Mg ha⁻¹ in UIGP, where the projected yield loss is up to 7, 11, 15, 22, and 33% relative to baseline yields with 1, 2, 3, 4, 5°C degrees rise in atmospheric temperatures.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              '1°C Temperature Increase (Monsoon)': [{'entity_name': '1°C Temperature Increase (Monsoon)',
#                'entity_type': 'Climate Drivers',
#                'description': 'However, a 20% increase in rainfall is projected to offset the yield loss due to 1°C rise in temperature.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              '20% Rainfall Increase': [{'entity_name': '20% Rainfall Increase',
#                'entity_type': 'Climate Drivers',
#                'description': 'However, a 20% increase in rainfall is projected to offset the yield loss due to 1°C rise in temperature.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              '2°C Temperature Increase (Monsoon)': [{'entity_name': '2°C Temperature Increase (Monsoon)',
#                'entity_type': 'Climate Drivers',
#                'description': 'Similarly, a 30% increase in rainfall is predicted to offset the adverse impact of 2°C rise in temperature.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              '30% Rainfall Increase': [{'entity_name': '30% Rainfall Increase',
#                'entity_type': 'Climate Drivers',
#                'description': 'Similarly, a 30% increase in rainfall is predicted to offset the adverse impact of 2°C rise in temperature.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Maize Yield Reduction (MIGP Monsoon)': [{'entity_name': 'Maize Yield Reduction (MIGP Monsoon)',
#                'entity_type': 'Crop Yield',
#                'description': 'In MIGP region, yield reduction of about 8–35% with 1–5°C rise in atmospheric temperature is projected.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Increased Rainfall (MIGP Monsoon)': [{'entity_name': 'Increased Rainfall (MIGP Monsoon)',
#                'entity_type': 'Climate Drivers',
#                'description': 'In this region, increase in rainfall is likely to offset the temperature rise up to 0.75°C and any increase beyond this temperature will adversely impact the yields, in spite of increase in rainfall.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              '0.75°C Temperature Offset Threshold (MIGP)': [{'entity_name': '0.75°C Temperature Offset Threshold (MIGP)',
#                'entity_type': 'Climate Drivers',
#                'description': 'In this region, increase in rainfall is likely to offset the temperature rise up to 0.75°C and any increase beyond this temperature will adversely impact the yields, in spite of increase in rainfall.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Maize Yield Reduction (SP Monsoon)': [{'entity_name': 'Maize Yield Reduction (SP Monsoon)',
#                'entity_type': 'Crop Yield',
#                'description': 'The SP region is also projected to experience adverse impact with -10, -15, -23, -27 and -35% reductions from the baseline yield levels at each 1°C rise in temperature.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              '10% Rainfall Increase (SP Monsoon)': [{'entity_name': '10% Rainfall Increase (SP Monsoon)',
#                'entity_type': 'Climate Drivers',
#                'description': 'A 10% increase in rainfall will offset the reduction in yield due to 1°C rise in temperature in this region.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Carbon Dioxide Concentration (CO2)': [{'entity_name': 'Carbon Dioxide Concentration (CO2)',
#                'entity_type': 'Climate Drivers',
#                'description': 'Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Maize Yield Benefit (CO2)': [{'entity_name': 'Maize Yield Benefit (CO2)',
#                'entity_type': 'Crop Yield',
#                'description': 'Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              '450 ppmV CO2 Concentration': [{'entity_name': '450 ppmV CO2 Concentration',
#                'entity_type': 'Climate Drivers',
#                'description': 'Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              '550 ppmV CO2 Concentration': [{'entity_name': '550 ppmV CO2 Concentration',
#                'entity_type': 'Climate Drivers',
#                'description': 'Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Mild Water Stress Conditions': [{'entity_name': 'Mild Water Stress Conditions',
#                'entity_type': 'Climate Drivers',
#                'description': 'The benefits are projected to be high in mild water stress conditions, but they are likely to reduce in severe water stress situations (Table 3).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Severe Water Stress Situations': [{'entity_name': 'Severe Water Stress Situations',
#                'entity_type': 'Climate Drivers',
#                'description': 'The benefits are projected to be high in mild water stress conditions, but they are likely to reduce in severe water stress situations (Table 3).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Table 3': [{'entity_name': 'Table 3',
#                'entity_type': 'Experimental Design',
#                'description': 'Table 3 Influence of atmospheric carbon dioxide concentration on maize yields in rainfall deficit conditions during monsoon season',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Assured Irrigation': [{'entity_name': 'Assured Irrigation',
#                'entity_type': 'Experimental Design',
#                'description': 'Maize crop during winter is provided with assured irrigation and thus yields about 1.5 times more than that of monsoon crop.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Winter Maize Yield (1.5x Monsoon)': [{'entity_name': 'Winter Maize Yield (1.5x Monsoon)',
#                'entity_type': 'Crop Yield',
#                'description': 'Maize crop during winter is provided with assured irrigation and thus yields about 1.5 times more than that of monsoon crop.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Winter Maize Grain Yield': [{'entity_name': 'Winter Maize Grain Yield',
#                'entity_type': 'Crop Yield',
#                'description': 'Winter maize grain yield reduced with increase in temperatures in SP and MIGP, but in UIGP rise in temperatures up to 2.7°C is likely to improve the maize yields.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              '2.7°C Temperature Rise (UIGP Winter)': [{'entity_name': '2.7°C Temperature Rise (UIGP Winter)',
#                'entity_type': 'Climate Drivers',
#                'description': 'Winter maize grain yield reduced with increase in temperatures in SP and MIGP, but in UIGP rise in temperatures up to 2.7°C is likely to improve the maize yields.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              '13% Maize Yield Increase (UIGP Winter)': [{'entity_name': '13% Maize Yield Increase (UIGP Winter)',
#                'entity_type': 'Crop Yield',
#                'description': 'In UIGP, this beneficial effect with rise in temperature is projected to be more up to 2°C rise (13% increase over current yields).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              '2°C Temperature Rise (UIGP Winter)': [{'entity_name': '2°C Temperature Rise (UIGP Winter)',
#                'entity_type': 'Climate Drivers',
#                'description': 'In UIGP, this beneficial effect with rise in temperature is projected to be more up to 2°C rise (13% increase over current yields).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Reduced Rainfall (Winter)': [{'entity_name': 'Reduced Rainfall (Winter)',
#                'entity_type': 'Climate Drivers',
#                'description': 'In this region, yield will improve with 2°C in spite of reduction in rainfall.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Increased Irrigation': [{'entity_name': 'Increased Irrigation',
#                'entity_type': 'Experimental Design',
#                'description': 'In the event of further increase in temperature to about 2.7°C, the reduction in yields can be offset only if rainfall is increased or more irrigation is provided.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Optimal Temperature for Grain Development': [{'entity_name': 'Optimal Temperature for Grain Development',
#                'entity_type': 'Climate Drivers',
#                'description': 'With temperature rise, the crop experiences conditions closer to optimal temperature during grain development, benefiting grain number.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Grain Number': [{'entity_name': 'Grain Number',
#                'entity_type': 'Crop Yield',
#                'description': 'With temperature rise, the crop experiences conditions closer to optimal temperature during grain development, benefiting grain number.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Low Temperature During Grain Filling': [{'entity_name': 'Low Temperature During Grain Filling',
#                'entity_type': 'Climate Drivers',
#                'description': 'Relatively low temperature during grain filling period required more days to satisfy thermal time requirement.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Thermal Time Requirement': [{'entity_name': 'Thermal Time Requirement',
#                'entity_type': 'Crop Type',
#                'description': 'Relatively low temperature during grain filling period required more days to satisfy thermal time requirement.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Average Maximum Temperatures (Winter)': [{'entity_name': 'Average Maximum Temperatures (Winter)',
#                'entity_type': 'Climate Drivers',
#                'description': 'However, in both MIGP and SP, where the average maximum temperatures during winter crop season are relatively higher (Table 2), any increase in temperature can cause reduction in yield.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Table 2': [{'entity_name': 'Table 2',
#                'entity_type': 'Experimental Design',
#                'description': 'However, in both MIGP and SP, where the average maximum temperatures during winter crop season are relatively higher (Table 2), any increase in temperature can cause reduction in yield.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Reduced Grain Number (UIGP)': [{'entity_name': 'Reduced Grain Number (UIGP)',
#                'entity_type': 'Crop Yield',
#                'description': 'In UIGP, rise in temperatures beyond 2.7°C caused reduction in yield mainly due to reduced number of grains.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Grain Filling Duration (GFD)': [{'entity_name': 'Grain Filling Duration (GFD)',
#                'entity_type': 'Crop Type',
#                'description': 'In UIGP, GFD was found to increase with rise in temperature because of current lower temperature during winter.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Individual Grain Weight': [{'entity_name': 'Individual Grain Weight',
#                'entity_type': 'Crop Yield',
#                'description': 'This limited the gains in spite of increase in GFD and individual grain weight.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Flowering Hastening': [{'entity_name': 'Flowering Hastening',
#                'entity_type': 'Crop Type',
#                'description': 'In all locations, flowering hastened due to increase in temperature.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              '2020 Climate Change Scenario': [{'entity_name': '2020 Climate Change Scenario',
#                'entity_type': 'Time',
#                'description': 'The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              '2050 Climate Change Scenario': [{'entity_name': '2050 Climate Change Scenario',
#                'entity_type': 'Time',
#                'description': 'The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              '2080 Climate Change Scenario': [{'entity_name': '2080 Climate Change Scenario',
#                'entity_type': 'Time',
#                'description': 'The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'IPCC 2007': [{'entity_name': 'IPCC 2007',
#                'entity_type': 'Experimental Design',
#                'description': 'This approach was followed because of reported spatio-temporal variations in climate change scenarios (IPCC 2007).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'},
#               {'entity_name': 'IPCC 2007',
#                'entity_type': 'IPCC 2007',
#                'description': 'Experimental Design',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Monsoon Maize Crop Productivity (Climate Change)': [{'entity_name': 'Monsoon Maize Crop Productivity (Climate Change)',
#                'entity_type': 'Crop Yield',
#                'description': 'The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Fig. 4a': [{'entity_name': 'Fig. 4a',
#                'entity_type': 'Experimental Design',
#                'description': 'The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Projected Rainfall Increase (Monsoon Climate Change)': [{'entity_name': 'Projected Rainfall Increase (Monsoon Climate Change)',
#                'entity_type': 'Climate Drivers',
#                'description': 'This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Improved Dry Matter Production': [{'entity_name': 'Improved Dry Matter Production',
#                'entity_type': 'Crop Yield',
#                'description': 'This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Increased Grain Number (Climate Change)': [{'entity_name': 'Increased Grain Number (Climate Change)',
#                'entity_type': 'Crop Yield',
#                'description': 'This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Maize Yields In Monsoon Season': [{'entity_name': 'Maize Yields In Monsoon Season',
#                'entity_type': 'Crop Yield',
#                'description': 'Results of simulation analysis indicate that maize yields in monsoon season are adversely affected due to rise in atmospheric temperatures in all three regions (Fig. 2a). The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Grain Yield': [{'entity_name': 'Grain Yield',
#                'entity_type': 'Crop Yield',
#                'description': 'Grain yield decreased with each degree rise in atmospheric temperature. However, the rate of decrease varied with location.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Projected Yield Loss Relative To Baseline (7-33%)': [{'entity_name': 'Projected Yield Loss Relative To Baseline (7-33%)',
#                'entity_type': 'Crop Yield',
#                'description': 'The mean baseline yield of rainfed maize crop is about 2 Mg ha⁻¹ in UIGP, where the projected yield loss is up to 7, 11, 15, 22, and 33% relative to baseline yields with 1, 2, 3, 4, 5°C degrees rise in atmospheric temperatures.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'MIGP Region': [{'entity_name': 'MIGP Region',
#                'entity_type': 'Location',
#                'description': 'In MIGP region, yield reduction of about 8–35% with 1–5°C rise in atmospheric temperature is projected. In this region, increase in rainfall is likely to offset the temperature rise up to 0.75°C and any increase beyond this temperature will adversely impact the yields, in spite of increase in rainfall.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'},
#               {'entity_name': 'MIGP Region',
#                'entity_type': 'Location',
#                'description': 'On the other hand, in MIGP, maize is likely to suffer yield loss in future scenarios.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Yield Reduction (8-35% In MIGP)': [{'entity_name': 'Yield Reduction (8-35% In MIGP)',
#                'entity_type': 'Crop Yield',
#                'description': 'In MIGP region, yield reduction of about 8–35% with 1–5°C rise in atmospheric temperature is projected.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Yield Reductions (-10% To -35% In SP)': [{'entity_name': 'Yield Reductions (-10% To -35% In SP)',
#                'entity_type': 'Crop Yield',
#                'description': 'The SP region is also projected to experience adverse impact with -10, -15, -23, -27 and -35% reductions from the baseline yield levels at each 1°C rise in temperature.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Increase In Carbon Dioxide': [{'entity_name': 'Increase In Carbon Dioxide',
#                'entity_type': 'Climate Drivers',
#                'description': 'Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV. The yield gains due to increase in atmospheric CO₂ concentration are projected to be more in SP regions (low rainfall area) followed by UIGP and MIGP regions.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Maize Yield Benefit (0.1-7.2%) Due To CO₂': [{'entity_name': 'Maize Yield Benefit (0.1-7.2%) Due To CO₂',
#                'entity_type': 'Crop Yield',
#                'description': 'Even though maize is a C4 plant, increase in carbon dioxide is projected to benefit the crop yield ranging from 0.1 to 3.4% at 450 ppmV and 0.6 to 7.2% at 550 ppmV.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Winter Maize Crop': [{'entity_name': 'Winter Maize Crop',
#                'entity_type': 'Crop Type',
#                'description': 'Maize crop during winter is provided with assured irrigation and thus yields about 1.5 times more than that of monsoon crop. Winter maize grain yield reduced with increase in temperatures in SP and MIGP, but in UIGP rise in temperatures up to 2.7°C is likely to improve the maize yields.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'},
#               {'entity_name': 'Winter Maize Crop',
#                'entity_type': 'Winter Maize Crop',
#                'description': 'Crop Type',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Winter Maize Grain Yield (1.5 Times More Than Monsoon)': [{'entity_name': 'Winter Maize Grain Yield (1.5 Times More Than Monsoon)',
#                'entity_type': 'Crop Yield',
#                'description': 'Maize crop during winter is provided with assured irrigation and thus yields about 1.5 times more than that of monsoon crop.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Improved Maize Yields (UIGP Winter)': [{'entity_name': 'Improved Maize Yields (UIGP Winter)',
#                'entity_type': 'Crop Yield',
#                'description': 'In UIGP, this beneficial effect with rise in temperature is projected to be more up to 2°C rise (13% increase over current yields).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Minimum Temperatures': [{'entity_name': 'Minimum Temperatures',
#                'entity_type': 'Climate Drivers',
#                'description': 'The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Maximum Temperatures': [{'entity_name': 'Maximum Temperatures',
#                'entity_type': 'Climate Drivers',
#                'description': 'The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'CO₂ Concentrations (Scenario Output)': [{'entity_name': 'CO₂ Concentrations (Scenario Output)',
#                'entity_type': 'Climate Drivers',
#                'description': 'The climate change scenario outputs of HadCM3 model on minimum and maximum temperatures and rainfall; CO₂ concentrations as per Bern CC model for 2020, 2050 and 2080 were coupled to InfoCrop-MAIZE model.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Productivity Of Monsoon Maize Crop (UIGP)': [{'entity_name': 'Productivity Of Monsoon Maize Crop (UIGP)',
#                'entity_type': 'Crop Yield',
#                'description': 'The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Projected Increase In Rainfall During Crop Season': [{'entity_name': 'Projected Increase In Rainfall During Crop Season',
#                'entity_type': 'Climate Drivers',
#                'description': 'This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Additional Availability Of Water': [{'entity_name': 'Additional Availability Of Water',
#                'entity_type': 'Climate Drivers',
#                'description': 'This implies that the maize crop may benefit from additional availability of water in spite of increase in temperature and related',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Temperature Rise Up To 2.7°C (UIGP)': [{'entity_name': 'Temperature Rise Up To 2.7°C (UIGP)',
#                'entity_type': 'Climate Drivers',
#                'description': 'In UIGP, rise in temperatures up to 2.7°C is likely to improve the maize yields. In the event of further increase in temperature to about 2.7°C, the reduction in yields can be offset only if rainfall is increased or more irrigation is provided.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Further Increase In Temperature': [{'entity_name': 'Further Increase In Temperature',
#                'entity_type': 'Climate Drivers',
#                'description': 'However, further increase in temperature is projected to reduce grain yields and the reductions are likely to be more than those at MIGP and SP (Fig. 3a).',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Rainfall Deficit Conditions': [{'entity_name': 'Rainfall Deficit Conditions',
#                'entity_type': 'Climate Drivers',
#                'description': 'Table 3 Influence of atmospheric carbon dioxide concentration on maize yields in rainfall deficit conditions during monsoon season.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Optimal Temperature During Grain Development': [{'entity_name': 'Optimal Temperature During Grain Development',
#                'entity_type': 'Climate Drivers',
#                'description': 'With temperature rise, the crop experiences conditions closer to optimal temperature during grain development, benefiting grain number.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Low Temperature During Grain Filling Period': [{'entity_name': 'Low Temperature During Grain Filling Period',
#                'entity_type': 'Climate Drivers',
#                'description': 'Relatively low temperature during grain filling period required more days to satisfy thermal time requirement.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Rise In Temperatures Beyond 2.7°C (UIGP)': [{'entity_name': 'Rise In Temperatures Beyond 2.7°C (UIGP)',
#                'entity_type': 'Climate Drivers',
#                'description': 'In UIGP, rise in temperatures beyond 2.7°C caused reduction in yield mainly due to reduced number of grains.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Reduction In Yield (UIGP, Beyond 2.7°C)': [{'entity_name': 'Reduction In Yield (UIGP, Beyond 2.7°C)',
#                'entity_type': 'Crop Yield',
#                'description': 'In UIGP, rise in temperatures beyond 2.7°C caused reduction in yield mainly due to reduced number of grains.',
#                'source_id': 'chunk-110b2a3996a446fc39fb457d4214d315',
#                'file_path': 'example.txt'}],
#              'Winter Maize Grain Yield Reduction': [{'entity_name': 'Winter Maize Grain Yield Reduction',
#                'entity_type': 'Crop Yield',
# ...
#                'description': 'Crop Yield',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'SP': [{'entity_name': 'SP',
#                'entity_type': 'SP',
#                'description': 'Location',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'SP Monsoon Maize Yield Loss': [{'entity_name': 'SP Monsoon Maize Yield Loss',
#                'entity_type': 'SP Monsoon Maize Yield Loss',
#                'description': 'Crop Yield',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Rise in Daytime Temperature (Monsoon)"|': [{'entity_name': 'Rise in Daytime Temperature (Monsoon)"|',
#                'entity_type': 'Rise in Daytime Temperature (Monsoon)',
#                'description': 'Climate Drivers',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Rise in Minimum Temperatures': [{'entity_name': 'Rise in Minimum Temperatures',
#                'entity_type': 'Rise in Minimum Temperatures',
#                'description': 'Climate Drivers',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Rainfall Change in MIGP': [{'entity_name': 'Rainfall Change in MIGP',
#                'entity_type': 'Rainfall Change in MIGP',
#                'description': 'Climate Drivers',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Monsoon Maize Crop in India': [{'entity_name': 'Monsoon Maize Crop in India',
#                'entity_type': 'Monsoon Maize Crop in India',
#                'description': 'Crop Type',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Spatio-temporal Variation in Climatic Conditions': [{'entity_name': 'Spatio-temporal Variation in Climatic Conditions',
#                'entity_type': 'Spatio-temporal Variation in Climatic Conditions',
#                'description': 'Climate Drivers',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'UIGP Winter Maize Yield Gain (2020-2050)"|': [{'entity_name': 'UIGP Winter Maize Yield Gain (2020-2050)"|',
#                'entity_type': 'UIGP Winter Maize Yield Gain (2020-2050)',
#                'description': 'Crop Yield',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'UIGP Winter Maize Yield Reduction (2080)"|': [{'entity_name': 'UIGP Winter Maize Yield Reduction (2080)"|',
#                'entity_type': 'UIGP Winter Maize Yield Reduction (2080)',
#                'description': 'Crop Yield',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'MIGP Winter Maize Yield Reduction': [{'entity_name': 'MIGP Winter Maize Yield Reduction',
#                'entity_type': 'MIGP Winter Maize Yield Reduction',
#                'description': 'Crop Yield',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'SP Winter Maize Yield Decline': [{'entity_name': 'SP Winter Maize Yield Decline',
#                'entity_type': 'SP Winter Maize Yield Decline',
#                'description': 'Crop Yield',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Low Winter Rainfall': [{'entity_name': 'Low Winter Rainfall',
#                'entity_type': 'Low Winter Rainfall',
#                'description': 'Climate Drivers',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Rise in Temperature (Winter Crop Season)"|': [{'entity_name': 'Rise in Temperature (Winter Crop Season)"|',
#                'entity_type': 'Rise in Temperature (Winter Crop Season)',
#                'description': 'Climate Drivers',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Climate Change Scenarios (IPCC 2007)': [{'entity_name': 'Climate Change Scenarios (IPCC 2007)',
#                'entity_type': 'Experimental Design',
#                'description': 'This approach was followed because of reported spatio-temporal variations in climate change scenarios (IPCC 2007).',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Monsoon Crop Analysis': [{'entity_name': 'Monsoon Crop Analysis',
#                'entity_type': 'Experimental Design',
#                'description': 'The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a).',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Winter Crop Analysis': [{'entity_name': 'Winter Crop Analysis',
#                'entity_type': 'Experimental Design',
#                'description': 'As far as maize crop grown in winter is concerned, yield gains are projected to be ~5% over current yield in 2020 scenario at UIGP and this benefit is likely to remain till 2050 (Fig. 4b).',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'India': [{'entity_name': 'India',
#                'entity_type': 'Location',
#                'description': 'Thus, the spatio-temporal variation in existing climatic conditions and projected changes in temperature and rainfall would bring about differential impacts on monsoon maize crop in India.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Monsoon Crop Season': [{'entity_name': 'Monsoon Crop Season',
#                'entity_type': 'Time',
#                'description': 'This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Post-2020 Scenario': [{'entity_name': 'Post-2020 Scenario',
#                'entity_type': 'Time',
#                'description': 'Winter maize in MIGP, currently a high yielding zone, is projected to suffer in post-2020 scenario.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Increased Monsoon Rainfall (UIGP)': [{'entity_name': 'Increased Monsoon Rainfall (UIGP)',
#                'entity_type': 'Climate Drivers',
#                'description': 'This is mainly due to projected increase in rainfall during crop season, which will provide scope for improved dry matter production and increase in grain number.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Increased Monsoon Temperature (UIGP)': [{'entity_name': 'Increased Monsoon Temperature (UIGP)',
#                'entity_type': 'Climate Drivers',
#                'description': 'This implies that the maize crop may benefit from additional availability of water in spite of increase in temperature and related reduction in crop duration by 3–4 days.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Rise in Monsoon Daytime Temperature (SP & MIGP)': [{'entity_name': 'Rise in Monsoon Daytime Temperature (SP & MIGP)',
#                'entity_type': 'Climate Drivers',
#                'description': 'Projected rise in daytime temperature during monsoon is higher in SP and MIGP as compared to UIGP region, even though minimum temperatures are projected to rise almost similarly in these locations.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Rise in Monsoon Minimum Temperatures': [{'entity_name': 'Rise in Monsoon Minimum Temperatures',
#                'entity_type': 'Climate Drivers',
#                'description': 'Projected rise in daytime temperature during monsoon is higher in SP and MIGP as compared to UIGP region, even though minimum temperatures are projected to rise almost similarly in these locations.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Changed Monsoon Rainfall (MIGP)': [{'entity_name': 'Changed Monsoon Rainfall (MIGP)',
#                'entity_type': 'Climate Drivers',
#                'description': 'Apart from this, rainfall is projected to increase in UIGP while it is likely to change in MIGP.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Rise in Winter Temperature (UIGP, 2020 & 2050)': [{'entity_name': 'Rise in Winter Temperature (UIGP, 2020 & 2050)',
#                'entity_type': 'Climate Drivers',
#                'description': 'The projected rise in temperature during winter crop season is more in UIGP in 2020 and 2050 than in MIGP and SP, particularly during later part of crop growth.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Insignificant Monsoon Maize Yield Change (UIGP)': [{'entity_name': 'Insignificant Monsoon Maize Yield Change (UIGP)',
#                'entity_type': 'Crop Yield',
#                'description': 'The analysis indicates that in UIGP region, climate change is projected to insignificantly affect the productivity of monsoon maize crop in 2020, 2050 and 2080 scenarios (Fig. 4a).',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Reduced Crop Duration (3–4 days)': [{'entity_name': 'Reduced Crop Duration (3–4 days)',
#                'entity_type': 'Crop Yield',
#                'description': 'This implies that the maize crop may benefit from additional availability of water in spite of increase in temperature and related reduction in crop duration by 3–4 days.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Monsoon Maize Yield Loss (~5% in MIGP, 2020)': [{'entity_name': 'Monsoon Maize Yield Loss (~5% in MIGP, 2020)',
#                'entity_type': 'Crop Yield',
#                'description': 'The loss from current yields is projected to be ~5%, ~13%, ~17% in 2020, 2050 and 2080, respectively.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Monsoon Maize Yield Loss (~13% in MIGP, 2050)': [{'entity_name': 'Monsoon Maize Yield Loss (~13% in MIGP, 2050)',
#                'entity_type': 'Crop Yield',
#                'description': 'The loss from current yields is projected to be ~5%, ~13%, ~17% in 2020, 2050 and 2080, respectively.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Monsoon Maize Yield Loss (~17% in MIGP, 2080)': [{'entity_name': 'Monsoon Maize Yield Loss (~17% in MIGP, 2080)',
#                'entity_type': 'Crop Yield',
#                'description': 'The loss from current yields is projected to be ~5%, ~13%, ~17% in 2020, 2050 and 2080, respectively.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Monsoon Maize Grain Yield Loss (21% in SP, 2020)': [{'entity_name': 'Monsoon Maize Grain Yield Loss (21% in SP, 2020)',
#                'entity_type': 'Crop Yield',
#                'description': 'In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Monsoon Maize Grain Yield Loss (35% in SP, 2050)': [{'entity_name': 'Monsoon Maize Grain Yield Loss (35% in SP, 2050)',
#                'entity_type': 'Crop Yield',
#                'description': 'In SP, monsoon season crop is projected to lose grain yield by 21% from current yields due to climate change by 2020 and 35% by 2050 and later.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Winter Maize Yield Gain (~5% in UIGP, 2020-2050)': [{'entity_name': 'Winter Maize Yield Gain (~5% in UIGP, 2020-2050)',
#                'entity_type': 'Crop Yield',
#                'description': 'As far as maize crop grown in winter is concerned, yield gains are projected to be ~5% over current yield in 2020 scenario at UIGP and this benefit is likely to remain till 2050 (Fig. 4b).',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Winter Maize Yield Reduction (25% in UIGP, 2080)': [{'entity_name': 'Winter Maize Yield Reduction (25% in UIGP, 2080)',
#                'entity_type': 'Crop Yield',
#                'description': 'However, in 2080 scenario, yields are projected to be reduced by 25% from current yields.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Winter Maize Yield Reduction (~50% in MIGP, 2050)': [{'entity_name': 'Winter Maize Yield Reduction (~50% in MIGP, 2050)',
#                'entity_type': 'Crop Yield',
#                'description': 'The reduction in yield is likely to be to the tune of ~50% by 2050 and about 60% by 2080.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Winter Maize Yield Reduction (60% in MIGP, 2080)': [{'entity_name': 'Winter Maize Yield Reduction (60% in MIGP, 2080)',
#                'entity_type': 'Crop Yield',
#                'description': 'The reduction in yield is likely to be to the tune of ~50% by 2050 and about 60% by 2080.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Winter Maize Yield Decline (13% in SP, 2020)': [{'entity_name': 'Winter Maize Yield Decline (13% in SP, 2020)',
#                'entity_type': 'Crop Yield',
#                'description': 'In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Winter Maize Yield Decline (17% in SP, 2050)': [{'entity_name': 'Winter Maize Yield Decline (17% in SP, 2050)',
#                'entity_type': 'Crop Yield',
#                'description': 'In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}],
#              'Winter Maize Yield Decline (21% in SP, 2080)': [{'entity_name': 'Winter Maize Yield Decline (21% in SP, 2080)',
#                'entity_type': 'Crop Yield',
#                'description': 'In SP region, yields are projected to decline by about 13% in 2020, 17% in 2050 and 21% in 2080.',
#                'source_id': 'chunk-b843b1d851c79158420cbc409bb3deac',
#                'file_path': 'example.txt'}]})

# %%
# Alternative: Simple raw data in separate files
def save_raw_nodes_txt(nodes, filename="raw_nodes.txt"):
    """Save raw nodes data to text file"""
    with open(filename, 'w', encoding='utf-8') as f:
        f.write("RAW NODES DATA\n")
        f.write("="*50 + "\n\n")
        for entity_name, entity_list in nodes.items():
            f.write(f"{entity_name}:\n{entity_list}\n\n")
    print(f"Raw nodes saved to: {filename}")
    return filename

def save_raw_edges_txt(edges, filename="raw_edges.txt"):
    """Save raw edges data to text file"""
    with open(filename, 'w', encoding='utf-8') as f:
        f.write("RAW EDGES DATA\n")
        f.write("="*50 + "\n\n")
        if edges:
            for i, edge in enumerate(edges, 1):
                f.write(f"Edge {i}: {edge}\n")
        else:
            f.write("No edges found.\n")
    print(f"Raw edges saved to: {filename}")
    return filename

# Uncomment these lines if you prefer simple raw data format:
save_raw_nodes_txt(nodes, "outputs/raw_nodes.txt")
save_raw_edges_txt(edges, "outputs/raw_edges.txt")
# Out:
# Raw nodes saved to: outputs/raw_nodes.txt
# Raw edges saved to: outputs/raw_edges.txt
# 'outputs/raw_edges.txt'
